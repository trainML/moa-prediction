# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

import os
from datetime import datetime

try:
    from iterstrat.ml_stratifiers import MultilabelStratifiedKFold  # trainML
except:
    sys.path.append("../input/iterative-stratification")  # kaggle
    from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

# %%
BASE_PATH = os.environ.get('TRAINML_DATA_PATH') if os.environ.get('TRAINML_DATA_PATH') else '../input/lish-moa'
BASE_PATH
# Out:
# '/opt/data'

# %%
train_features = pd.read_csv(f'{BASE_PATH}/train_features.csv')
train_targets = pd.read_csv(f'{BASE_PATH}/train_targets_scored.csv')
test_features = pd.read_csv(f'{BASE_PATH}/test_features.csv')

sample_submission = pd.read_csv(f'{BASE_PATH}/sample_submission.csv')

# %%
def preprocess(df):
    df = df.copy()
    df.loc[:, 'cp_type'] = df.loc[:, 'cp_type'].map({'trt_cp': 0, 'ctl_vehicle': 1})
    df.loc[:, 'cp_dose'] = df.loc[:, 'cp_dose'].map({'D1': 0, 'D2': 1})
    del df['sig_id']
    return df

train_data = preprocess(train_features)
test_data = preprocess(test_features)

del train_targets['sig_id']

train_targets = train_targets.loc[train_data['cp_type']==0].reset_index(drop=True)
train_data = train_data.loc[train_data['cp_type']==0].reset_index(drop=True)

X = train_data.values
Y = train_targets.values
X_test = test_data.values

# %%
class MoaModel(nn.Module):
    def __init__(
        self,
        num_columns,
        model_state=None,
        layer1_outputs=2048,
        layer1_dropout=0.2,
        layer2_outputs=1048,
        layer2_dropout=0.5,
        layer3_enable=False,
        layer3_outputs=None,
        layer3_dropout=0.5,
        final_layer_dropout=0.5,
    ):
        super(MoaModel, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_columns)
        self.dropout1 = nn.Dropout(layer1_dropout)
        self.dense1 = nn.utils.weight_norm(nn.Linear(num_columns, layer1_outputs))

        self.batch_norm2 = nn.BatchNorm1d(layer1_outputs)
        self.dropout2 = nn.Dropout(layer2_dropout)
        self.dense2 = nn.utils.weight_norm(nn.Linear(layer1_outputs, layer2_outputs))

        self.layer3 = layer3_enable
        if self.layer3:
            self.batch_norm3 = nn.BatchNorm1d(layer2_outputs)
            self.dropout3 = nn.Dropout(layer3_dropout)
            self.dense3 = nn.utils.weight_norm(
                nn.Linear(layer2_outputs, layer3_outputs)
            )

        final_layer_inputs = layer3_outputs if self.layer3 else layer2_outputs
        self.batch_norm_final = nn.BatchNorm1d(final_layer_inputs)
        self.dropout_final = nn.Dropout(final_layer_dropout)
        self.dense_final = nn.utils.weight_norm(nn.Linear(final_layer_inputs, 206))

    def forward(self, X):
        X = self.batch_norm1(X)
        X = self.dropout1(X)
        X = F.relu(self.dense1(X))

        X = self.batch_norm2(X)
        X = self.dropout2(X)
        X = F.relu(self.dense2(X))

        if self.layer3:
            X = self.batch_norm3(X)
            X = self.dropout3(X)
            X = F.relu(self.dense3(X))

        X = self.batch_norm_final(X)
        X = self.dropout_final(X)
        X = F.sigmoid(self.dense_final(X))

        return X

    def _load_from_file(self, file):
        self.load_state_dict(torch.load(file))

    def save(self, file):
        torch.save(self.state_dict(), file)


def batch_gd(model, device, criterion, optimizer, train_loader, val_loader, epochs):
    train_losses = np.zeros(epochs)
    val_losses = np.zeros(epochs)
    for it in range(epochs):
        t0 = datetime.now()

        model.train()
        train_loss = []
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)

            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, targets)

            loss.backward()
            optimizer.step()

            train_loss.append(loss.item() / len(train_loader))

        train_loss = np.mean(train_loss)

        model.eval()
        val_loss = []
        for inputs, targets in val_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            val_loss.append(loss.item() / len(val_loader))
        val_loss = np.mean(val_loss)

        train_losses[it] = train_loss
        val_losses[it] = val_loss

        dt = datetime.now() - t0
        print(
            f"Epoch {it+1}/{epochs}, Train Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}, Duration {dt}"
        )

    return train_losses, val_losses


def predict(model, device, data_loader):
    model.eval()
    preds = []

    for inputs, _ in data_loader:
        inputs = inputs.to(device)

        with torch.no_grad():
            outputs = model(inputs)

        preds.append(outputs.detach().cpu().numpy())

    preds = np.concatenate(preds)

    return preds

# %%
class MoaDataset(Dataset):
    def __init__(self, features, targets, mode="train"):
        self.mode = mode
        self.data = features
        if mode == "train":
            self.targets = targets

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        if self.mode == "train":
            return torch.FloatTensor(self.data[idx]), torch.FloatTensor(
                self.targets[idx]
            )
        elif self.mode == "eval":
            return torch.FloatTensor(self.data[idx]), 0


def train(model, device, X, Y, n_splits=10, batch_size=4096, epochs=50):
    kfold = MultilabelStratifiedKFold(n_splits=n_splits, random_state=42, shuffle=True)

    criterion = nn.BCELoss()
    optimizer = torch.optim.Adam(model.parameters())

    train_losses = np.array([])
    val_losses = np.array([])

    for n, (tr, te) in enumerate(kfold.split(X, Y)):
        X_train, X_val = X[tr], X[te]
        y_train, y_val = Y[tr], Y[te]

        train_dataset = MoaDataset(X_train, y_train)
        val_dataset = MoaDataset(X_val, y_val)
        train_loader = torch.utils.data.DataLoader(
            dataset=train_dataset, batch_size=batch_size, shuffle=True
        )
        val_loader = torch.utils.data.DataLoader(
            dataset=val_dataset, batch_size=batch_size, shuffle=False
        )
        split_train_losses, split_val_losses = batch_gd(
            model, device, criterion, optimizer, train_loader, val_loader, epochs
        )
        print(
            f"Fold {n+1}, final train loss: {split_train_losses[epochs-1]:5.5f}, final train loss: {split_val_losses[epochs-1]:5.5f}"
        )
        train_losses = np.concatenate((train_losses, split_train_losses))
        val_losses = np.concatenate((val_losses, split_val_losses))

    model.save("latest_model")
    return train_losses, val_losses

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = MoaModel(train_data.shape[1])
model.to(device)
# Out:
# MoaModel(
#   (batch_norm1): BatchNorm1d(875, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (dense1): Linear(in_features=875, out_features=2048, bias=True)
#   (batch_norm2): BatchNorm1d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (dense2): Linear(in_features=2048, out_features=1048, bias=True)
#   (batch_norm_final): BatchNorm1d(1048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout_final): Dropout(p=0.5, inplace=False)
#   (dense_final): Linear(in_features=1048, out_features=206, bias=True)
# )

# %%
batch_size=4096
n_splits=10
epochs=50
train_losses, val_losses = train(model, device, X, Y)
# Out:
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1639: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Epoch 1/50, Train Loss: 0.1491, Validation Loss: 0.7145, Duration 0:00:00.629623
# Epoch 2/50, Train Loss: 0.1436, Validation Loss: 0.6988, Duration 0:00:00.612749
# Epoch 3/50, Train Loss: 0.1414, Validation Loss: 0.6835, Duration 0:00:00.562874
# Epoch 4/50, Train Loss: 0.1379, Validation Loss: 0.6623, Duration 0:00:00.621544
# Epoch 5/50, Train Loss: 0.1328, Validation Loss: 0.6321, Duration 0:00:00.615534
# Epoch 6/50, Train Loss: 0.1258, Validation Loss: 0.5836, Duration 0:00:00.603986
# Epoch 7/50, Train Loss: 0.1164, Validation Loss: 0.5290, Duration 0:00:00.630811
# Epoch 8/50, Train Loss: 0.1055, Validation Loss: 0.4790, Duration 0:00:00.552778
# Epoch 9/50, Train Loss: 0.0940, Validation Loss: 0.4162, Duration 0:00:00.632763
# Epoch 10/50, Train Loss: 0.0821, Validation Loss: 0.3711, Duration 0:00:00.603415
# Epoch 11/50, Train Loss: 0.0708, Validation Loss: 0.3185, Duration 0:00:00.617801
# Epoch 12/50, Train Loss: 0.0610, Validation Loss: 0.2714, Duration 0:00:00.610775
# Epoch 13/50, Train Loss: 0.0527, Validation Loss: 0.2271, Duration 0:00:00.566631
# Epoch 14/50, Train Loss: 0.0461, Validation Loss: 0.2074, Duration 0:00:00.613493
# Epoch 15/50, Train Loss: 0.0403, Validation Loss: 0.1809, Duration 0:00:00.609371
# Epoch 16/50, Train Loss: 0.0356, Validation Loss: 0.1569, Duration 0:00:00.630866
# Epoch 17/50, Train Loss: 0.0319, Validation Loss: 0.1442, Duration 0:00:00.561326
# Epoch 18/50, Train Loss: 0.0288, Validation Loss: 0.1315, Duration 0:00:00.649108
# Epoch 19/50, Train Loss: 0.0261, Validation Loss: 0.1201, Duration 0:00:00.627475
# Epoch 20/50, Train Loss: 0.0235, Validation Loss: 0.1053, Duration 0:00:00.635544
# Epoch 21/50, Train Loss: 0.0216, Validation Loss: 0.0996, Duration 0:00:00.623901
# Epoch 22/50, Train Loss: 0.0196, Validation Loss: 0.0916, Duration 0:00:00.571449
# Epoch 23/50, Train Loss: 0.0184, Validation Loss: 0.0845, Duration 0:00:00.606107
# Epoch 24/50, Train Loss: 0.0173, Validation Loss: 0.0801, Duration 0:00:00.639266
# Epoch 25/50, Train Loss: 0.0160, Validation Loss: 0.0738, Duration 0:00:00.615673
# Epoch 26/50, Train Loss: 0.0148, Validation Loss: 0.0683, Duration 0:00:00.621091
# Epoch 27/50, Train Loss: 0.0149, Validation Loss: 0.0652, Duration 0:00:00.561999
# Epoch 28/50, Train Loss: 0.0142, Validation Loss: 0.0624, Duration 0:00:00.639824
# Epoch 29/50, Train Loss: 0.0124, Validation Loss: 0.0579, Duration 0:00:00.623227
# Epoch 30/50, Train Loss: 0.0118, Validation Loss: 0.0528, Duration 0:00:00.624792
# Epoch 31/50, Train Loss: 0.0112, Validation Loss: 0.0520, Duration 0:00:00.612928
# Epoch 32/50, Train Loss: 0.0105, Validation Loss: 0.0491, Duration 0:00:00.555379
# Epoch 33/50, Train Loss: 0.0101, Validation Loss: 0.0471, Duration 0:00:00.614799
# Epoch 34/50, Train Loss: 0.0097, Validation Loss: 0.0458, Duration 0:00:00.624351
# Epoch 35/50, Train Loss: 0.0095, Validation Loss: 0.0464, Duration 0:00:00.629135
# Epoch 36/50, Train Loss: 0.0090, Validation Loss: 0.0433, Duration 0:00:00.607103
# Epoch 37/50, Train Loss: 0.0087, Validation Loss: 0.0410, Duration 0:00:00.551474
# Epoch 38/50, Train Loss: 0.0084, Validation Loss: 0.0392, Duration 0:00:00.637352
# Epoch 39/50, Train Loss: 0.0082, Validation Loss: 0.0384, Duration 0:00:00.615049
# Epoch 40/50, Train Loss: 0.0079, Validation Loss: 0.0380, Duration 0:00:00.618420
# Epoch 41/50, Train Loss: 0.0078, Validation Loss: 0.0374, Duration 0:00:00.570037
# Epoch 42/50, Train Loss: 0.0076, Validation Loss: 0.0363, Duration 0:00:00.623633
# Epoch 43/50, Train Loss: 0.0074, Validation Loss: 0.0355, Duration 0:00:00.625864
# Epoch 44/50, Train Loss: 0.0073, Validation Loss: 0.0348, Duration 0:00:00.618584
# Epoch 45/50, Train Loss: 0.0071, Validation Loss: 0.0337, Duration 0:00:00.604708
# Epoch 46/50, Train Loss: 0.0070, Validation Loss: 0.0329, Duration 0:00:00.559620
# Epoch 47/50, Train Loss: 0.0068, Validation Loss: 0.0329, Duration 0:00:00.619046
# Epoch 48/50, Train Loss: 0.0067, Validation Loss: 0.0322, Duration 0:00:00.611797
# Epoch 49/50, Train Loss: 0.0065, Validation Loss: 0.0313, Duration 0:00:00.614392
# Epoch 50/50, Train Loss: 0.0063, Validation Loss: 0.0298, Duration 0:00:00.619799
# Fold 0, final train loss: 0.00632, final train loss: 0.02976
# Epoch 1/50, Train Loss: 0.0061, Validation Loss: 0.0296, Duration 0:00:00.587884
# Epoch 2/50, Train Loss: 0.0061, Validation Loss: 0.0296, Duration 0:00:00.624999
# Epoch 3/50, Train Loss: 0.0061, Validation Loss: 0.0294, Duration 0:00:00.605300
# Epoch 4/50, Train Loss: 0.0061, Validation Loss: 0.0289, Duration 0:00:00.604292
# Epoch 5/50, Train Loss: 0.0058, Validation Loss: 0.0283, Duration 0:00:00.615234
# Epoch 6/50, Train Loss: 0.0057, Validation Loss: 0.0276, Duration 0:00:00.552093
# Epoch 7/50, Train Loss: 0.0058, Validation Loss: 0.0277, Duration 0:00:00.638788
# Epoch 8/50, Train Loss: 0.0057, Validation Loss: 0.0273, Duration 0:00:00.612643
# Epoch 9/50, Train Loss: 0.0057, Validation Loss: 0.0270, Duration 0:00:00.612403
# Epoch 10/50, Train Loss: 0.0054, Validation Loss: 0.0266, Duration 0:00:00.606927
# Epoch 11/50, Train Loss: 0.0055, Validation Loss: 0.0262, Duration 0:00:00.576916
# Epoch 12/50, Train Loss: 0.0053, Validation Loss: 0.0256, Duration 0:00:00.613650
# Epoch 13/50, Train Loss: 0.0052, Validation Loss: 0.0255, Duration 0:00:00.625405
# Epoch 14/50, Train Loss: 0.0052, Validation Loss: 0.0253, Duration 0:00:00.617659
# Epoch 15/50, Train Loss: 0.0052, Validation Loss: 0.0251, Duration 0:00:00.580939
# Epoch 16/50, Train Loss: 0.0051, Validation Loss: 0.0250, Duration 0:00:00.626956
# Epoch 17/50, Train Loss: 0.0050, Validation Loss: 0.0245, Duration 0:00:00.608690
# Epoch 18/50, Train Loss: 0.0050, Validation Loss: 0.0244, Duration 0:00:00.639563
# Epoch 19/50, Train Loss: 0.0049, Validation Loss: 0.0242, Duration 0:00:00.610974
# Epoch 20/50, Train Loss: 0.0049, Validation Loss: 0.0238, Duration 0:00:00.551543
# Epoch 21/50, Train Loss: 0.0048, Validation Loss: 0.0235, Duration 0:00:00.664021
# Epoch 22/50, Train Loss: 0.0048, Validation Loss: 0.0234, Duration 0:00:00.610481
# Epoch 23/50, Train Loss: 0.0048, Validation Loss: 0.0236, Duration 0:00:00.652851
# Epoch 24/50, Train Loss: 0.0048, Validation Loss: 0.0232, Duration 0:00:00.616526
# Epoch 25/50, Train Loss: 0.0047, Validation Loss: 0.0232, Duration 0:00:00.550980
# Epoch 26/50, Train Loss: 0.0047, Validation Loss: 0.0230, Duration 0:00:00.608176
# Epoch 27/50, Train Loss: 0.0047, Validation Loss: 0.0228, Duration 0:00:00.623485
# Epoch 28/50, Train Loss: 0.0046, Validation Loss: 0.0227, Duration 0:00:00.614196
# Epoch 29/50, Train Loss: 0.0046, Validation Loss: 0.0225, Duration 0:00:00.613656
# Epoch 30/50, Train Loss: 0.0045, Validation Loss: 0.0224, Duration 0:00:00.563738
# Epoch 31/50, Train Loss: 0.0046, Validation Loss: 0.0222, Duration 0:00:00.631768
# Epoch 32/50, Train Loss: 0.0045, Validation Loss: 0.0220, Duration 0:00:00.616511
# Epoch 33/50, Train Loss: 0.0044, Validation Loss: 0.0219, Duration 0:00:00.624292
# Epoch 34/50, Train Loss: 0.0044, Validation Loss: 0.0218, Duration 0:00:00.625086
# Epoch 35/50, Train Loss: 0.0044, Validation Loss: 0.0216, Duration 0:00:00.568719
# Epoch 36/50, Train Loss: 0.0044, Validation Loss: 0.0218, Duration 0:00:00.616555
# Epoch 37/50, Train Loss: 0.0043, Validation Loss: 0.0218, Duration 0:00:00.605489
# Epoch 38/50, Train Loss: 0.0044, Validation Loss: 0.0214, Duration 0:00:00.614749
# Epoch 39/50, Train Loss: 0.0043, Validation Loss: 0.0214, Duration 0:00:00.588919
# Epoch 40/50, Train Loss: 0.0043, Validation Loss: 0.0213, Duration 0:00:00.606144
# Epoch 41/50, Train Loss: 0.0043, Validation Loss: 0.0212, Duration 0:00:00.619805
# Epoch 42/50, Train Loss: 0.0042, Validation Loss: 0.0209, Duration 0:00:00.605286
# Epoch 43/50, Train Loss: 0.0044, Validation Loss: 0.0212, Duration 0:00:00.621618
# Epoch 44/50, Train Loss: 0.0043, Validation Loss: 0.0217, Duration 0:00:00.570333
# Epoch 45/50, Train Loss: 0.0043, Validation Loss: 0.0218, Duration 0:00:00.624513
# Epoch 46/50, Train Loss: 0.0043, Validation Loss: 0.0214, Duration 0:00:00.611637
# Epoch 47/50, Train Loss: 0.0042, Validation Loss: 0.0212, Duration 0:00:00.626482
# Epoch 48/50, Train Loss: 0.0042, Validation Loss: 0.0209, Duration 0:00:00.638413
# Epoch 49/50, Train Loss: 0.0042, Validation Loss: 0.0206, Duration 0:00:00.565714
# Epoch 50/50, Train Loss: 0.0042, Validation Loss: 0.0205, Duration 0:00:00.610140
# Fold 1, final train loss: 0.00417, final train loss: 0.02049
# Epoch 1/50, Train Loss: 0.0041, Validation Loss: 0.0197, Duration 0:00:00.625474
# Epoch 2/50, Train Loss: 0.0041, Validation Loss: 0.0196, Duration 0:00:00.614833
# Epoch 3/50, Train Loss: 0.0041, Validation Loss: 0.0195, Duration 0:00:00.615409
# Epoch 4/50, Train Loss: 0.0041, Validation Loss: 0.0196, Duration 0:00:00.550121
# Epoch 5/50, Train Loss: 0.0040, Validation Loss: 0.0195, Duration 0:00:00.648450
# Epoch 6/50, Train Loss: 0.0041, Validation Loss: 0.0194, Duration 0:00:00.603834
# Epoch 7/50, Train Loss: 0.0040, Validation Loss: 0.0193, Duration 0:00:00.618504
# Epoch 8/50, Train Loss: 0.0040, Validation Loss: 0.0193, Duration 0:00:00.628314
# Epoch 9/50, Train Loss: 0.0040, Validation Loss: 0.0194, Duration 0:00:00.561296
# Epoch 10/50, Train Loss: 0.0040, Validation Loss: 0.0197, Duration 0:00:00.632692
# Epoch 11/50, Train Loss: 0.0040, Validation Loss: 0.0193, Duration 0:00:00.639407
# Epoch 12/50, Train Loss: 0.0040, Validation Loss: 0.0192, Duration 0:00:00.604745
# Epoch 13/50, Train Loss: 0.0040, Validation Loss: 0.0191, Duration 0:00:00.567394
# Epoch 14/50, Train Loss: 0.0043, Validation Loss: 0.0194, Duration 0:00:00.635173
# Epoch 15/50, Train Loss: 0.0040, Validation Loss: 0.0194, Duration 0:00:00.613578
# Epoch 16/50, Train Loss: 0.0040, Validation Loss: 0.0194, Duration 0:00:00.615615
# Epoch 17/50, Train Loss: 0.0040, Validation Loss: 0.0192, Duration 0:00:00.621901
# Epoch 18/50, Train Loss: 0.0039, Validation Loss: 0.0191, Duration 0:00:00.572940
# Epoch 19/50, Train Loss: 0.0039, Validation Loss: 0.0190, Duration 0:00:00.608063
# Epoch 20/50, Train Loss: 0.0039, Validation Loss: 0.0189, Duration 0:00:00.623528
# Epoch 21/50, Train Loss: 0.0039, Validation Loss: 0.0190, Duration 0:00:00.626232
# Epoch 22/50, Train Loss: 0.0039, Validation Loss: 0.0187, Duration 0:00:00.616594
# Epoch 23/50, Train Loss: 0.0038, Validation Loss: 0.0187, Duration 0:00:00.565102
# Epoch 24/50, Train Loss: 0.0038, Validation Loss: 0.0186, Duration 0:00:00.617564
# Epoch 25/50, Train Loss: 0.0038, Validation Loss: 0.0187, Duration 0:00:00.606816
# Epoch 26/50, Train Loss: 0.0038, Validation Loss: 0.0185, Duration 0:00:00.633204
# Epoch 27/50, Train Loss: 0.0038, Validation Loss: 0.0186, Duration 0:00:00.623257
# Epoch 28/50, Train Loss: 0.0038, Validation Loss: 0.0185, Duration 0:00:00.549956
# Epoch 29/50, Train Loss: 0.0038, Validation Loss: 0.0185, Duration 0:00:00.615286
# Epoch 30/50, Train Loss: 0.0037, Validation Loss: 0.0184, Duration 0:00:00.616574
# Epoch 31/50, Train Loss: 0.0038, Validation Loss: 0.0184, Duration 0:00:00.612581
# Epoch 32/50, Train Loss: 0.0038, Validation Loss: 0.0185, Duration 0:00:00.605049
# Epoch 33/50, Train Loss: 0.0037, Validation Loss: 0.0185, Duration 0:00:00.568414
# Epoch 34/50, Train Loss: 0.0037, Validation Loss: 0.0184, Duration 0:00:00.603948
# Epoch 35/50, Train Loss: 0.0037, Validation Loss: 0.0184, Duration 0:00:00.611153
# Epoch 36/50, Train Loss: 0.0037, Validation Loss: 0.0183, Duration 0:00:00.634191
# Epoch 37/50, Train Loss: 0.0037, Validation Loss: 0.0183, Duration 0:00:00.578497
# Epoch 38/50, Train Loss: 0.0037, Validation Loss: 0.0182, Duration 0:00:00.622591
# Epoch 39/50, Train Loss: 0.0037, Validation Loss: 0.0182, Duration 0:00:00.606963
# Epoch 40/50, Train Loss: 0.0037, Validation Loss: 0.0182, Duration 0:00:00.604429
# Epoch 41/50, Train Loss: 0.0037, Validation Loss: 0.0181, Duration 0:00:00.621857
# Epoch 42/50, Train Loss: 0.0038, Validation Loss: 0.0184, Duration 0:00:00.568613
# Epoch 43/50, Train Loss: 0.0037, Validation Loss: 0.0184, Duration 0:00:00.624613
# Epoch 44/50, Train Loss: 0.0037, Validation Loss: 0.0184, Duration 0:00:00.615260
# Epoch 45/50, Train Loss: 0.0037, Validation Loss: 0.0184, Duration 0:00:00.629127
# Epoch 46/50, Train Loss: 0.0037, Validation Loss: 0.0182, Duration 0:00:00.646933
# Epoch 47/50, Train Loss: 0.0036, Validation Loss: 0.0181, Duration 0:00:00.563947
# Epoch 48/50, Train Loss: 0.0036, Validation Loss: 0.0181, Duration 0:00:00.630974
# Epoch 49/50, Train Loss: 0.0036, Validation Loss: 0.0180, Duration 0:00:00.632615
# Epoch 50/50, Train Loss: 0.0036, Validation Loss: 0.0180, Duration 0:00:00.627704
# Fold 2, final train loss: 0.00361, final train loss: 0.01796
# Epoch 1/50, Train Loss: 0.0036, Validation Loss: 0.0172, Duration 0:00:00.610364
# Epoch 2/50, Train Loss: 0.0036, Validation Loss: 0.0171, Duration 0:00:00.576559
# Epoch 3/50, Train Loss: 0.0036, Validation Loss: 0.0171, Duration 0:00:00.637448
# Epoch 4/50, Train Loss: 0.0036, Validation Loss: 0.0172, Duration 0:00:00.620278
# Epoch 5/50, Train Loss: 0.0036, Validation Loss: 0.0171, Duration 0:00:00.641361
# Epoch 6/50, Train Loss: 0.0036, Validation Loss: 0.0171, Duration 0:00:00.612187
# Epoch 7/50, Train Loss: 0.0036, Validation Loss: 0.0171, Duration 0:00:00.552124
# Epoch 8/50, Train Loss: 0.0035, Validation Loss: 0.0171, Duration 0:00:00.631400
# Epoch 9/50, Train Loss: 0.0036, Validation Loss: 0.0171, Duration 0:00:00.616525
# Epoch 10/50, Train Loss: 0.0035, Validation Loss: 0.0171, Duration 0:00:00.615593
# Epoch 11/50, Train Loss: 0.0035, Validation Loss: 0.0171, Duration 0:00:00.552092
# Epoch 12/50, Train Loss: 0.0035, Validation Loss: 0.0171, Duration 0:00:00.631963
# Epoch 13/50, Train Loss: 0.0035, Validation Loss: 0.0170, Duration 0:00:00.644286
# Epoch 14/50, Train Loss: 0.0035, Validation Loss: 0.0171, Duration 0:00:00.616808
# Epoch 15/50, Train Loss: 0.0035, Validation Loss: 0.0171, Duration 0:00:00.630229
# Epoch 16/50, Train Loss: 0.0035, Validation Loss: 0.0171, Duration 0:00:00.563856
# Epoch 17/50, Train Loss: 0.0035, Validation Loss: 0.0170, Duration 0:00:00.624261
# Epoch 18/50, Train Loss: 0.0035, Validation Loss: 0.0170, Duration 0:00:00.612788
# Epoch 19/50, Train Loss: 0.0034, Validation Loss: 0.0170, Duration 0:00:00.614817
# Epoch 20/50, Train Loss: 0.0034, Validation Loss: 0.0170, Duration 0:00:00.612908
# Epoch 21/50, Train Loss: 0.0034, Validation Loss: 0.0170, Duration 0:00:00.556361
# Epoch 22/50, Train Loss: 0.0034, Validation Loss: 0.0170, Duration 0:00:00.606019
# Epoch 23/50, Train Loss: 0.0034, Validation Loss: 0.0170, Duration 0:00:00.635557
# Epoch 24/50, Train Loss: 0.0034, Validation Loss: 0.0170, Duration 0:00:00.628411
# Epoch 25/50, Train Loss: 0.0035, Validation Loss: 0.0170, Duration 0:00:00.615941
# Epoch 26/50, Train Loss: 0.0034, Validation Loss: 0.0171, Duration 0:00:00.569122
# Epoch 27/50, Train Loss: 0.0034, Validation Loss: 0.0170, Duration 0:00:00.622173
# Epoch 28/50, Train Loss: 0.0034, Validation Loss: 0.0170, Duration 0:00:00.627743
# Epoch 29/50, Train Loss: 0.0034, Validation Loss: 0.0169, Duration 0:00:00.609805
# Epoch 30/50, Train Loss: 0.0034, Validation Loss: 0.0169, Duration 0:00:00.618893
# Epoch 31/50, Train Loss: 0.0033, Validation Loss: 0.0169, Duration 0:00:00.565908
# Epoch 32/50, Train Loss: 0.0033, Validation Loss: 0.0169, Duration 0:00:00.612973
# Epoch 33/50, Train Loss: 0.0033, Validation Loss: 0.0169, Duration 0:00:00.624866
# Epoch 34/50, Train Loss: 0.0033, Validation Loss: 0.0169, Duration 0:00:00.611975
# Epoch 35/50, Train Loss: 0.0033, Validation Loss: 0.0169, Duration 0:00:00.564438
# Epoch 36/50, Train Loss: 0.0033, Validation Loss: 0.0169, Duration 0:00:00.626245
# Epoch 37/50, Train Loss: 0.0033, Validation Loss: 0.0168, Duration 0:00:00.613438
# Epoch 38/50, Train Loss: 0.0033, Validation Loss: 0.0168, Duration 0:00:00.608013
# Epoch 39/50, Train Loss: 0.0033, Validation Loss: 0.0168, Duration 0:00:00.643955
# Epoch 40/50, Train Loss: 0.0033, Validation Loss: 0.0169, Duration 0:00:00.602984
# Epoch 41/50, Train Loss: 0.0033, Validation Loss: 0.0169, Duration 0:00:00.624600
# Epoch 42/50, Train Loss: 0.0033, Validation Loss: 0.0168, Duration 0:00:00.625248
# Epoch 43/50, Train Loss: 0.0032, Validation Loss: 0.0168, Duration 0:00:00.641224
# Epoch 44/50, Train Loss: 0.0032, Validation Loss: 0.0168, Duration 0:00:00.605026
# Epoch 45/50, Train Loss: 0.0032, Validation Loss: 0.0169, Duration 0:00:00.571170
# Epoch 46/50, Train Loss: 0.0032, Validation Loss: 0.0168, Duration 0:00:00.643308
# Epoch 47/50, Train Loss: 0.0032, Validation Loss: 0.0168, Duration 0:00:00.605436
# Epoch 48/50, Train Loss: 0.0032, Validation Loss: 0.0168, Duration 0:00:00.617765
# Epoch 49/50, Train Loss: 0.0032, Validation Loss: 0.0168, Duration 0:00:00.638452
# Epoch 50/50, Train Loss: 0.0032, Validation Loss: 0.0168, Duration 0:00:00.578802
# Fold 3, final train loss: 0.00319, final train loss: 0.01676
# Epoch 1/50, Train Loss: 0.0032, Validation Loss: 0.0148, Duration 0:00:00.606644
# Epoch 2/50, Train Loss: 0.0032, Validation Loss: 0.0148, Duration 0:00:00.608295
# Epoch 3/50, Train Loss: 0.0032, Validation Loss: 0.0148, Duration 0:00:00.614051
# Epoch 4/50, Train Loss: 0.0032, Validation Loss: 0.0149, Duration 0:00:00.615580
# Epoch 5/50, Train Loss: 0.0032, Validation Loss: 0.0149, Duration 0:00:00.565864
# Epoch 6/50, Train Loss: 0.0032, Validation Loss: 0.0149, Duration 0:00:00.611808
# Epoch 7/50, Train Loss: 0.0032, Validation Loss: 0.0148, Duration 0:00:00.604782
# Epoch 8/50, Train Loss: 0.0032, Validation Loss: 0.0149, Duration 0:00:00.606199
# Epoch 9/50, Train Loss: 0.0031, Validation Loss: 0.0150, Duration 0:00:00.560302
# Epoch 10/50, Train Loss: 0.0031, Validation Loss: 0.0150, Duration 0:00:00.630675
# Epoch 11/50, Train Loss: 0.0031, Validation Loss: 0.0150, Duration 0:00:00.619581
# Epoch 12/50, Train Loss: 0.0031, Validation Loss: 0.0149, Duration 0:00:00.630815
# Epoch 13/50, Train Loss: 0.0031, Validation Loss: 0.0151, Duration 0:00:00.629718
# Epoch 14/50, Train Loss: 0.0031, Validation Loss: 0.0152, Duration 0:00:00.570677
# Epoch 15/50, Train Loss: 0.0031, Validation Loss: 0.0152, Duration 0:00:00.611078
# Epoch 16/50, Train Loss: 0.0031, Validation Loss: 0.0152, Duration 0:00:00.626414
# Epoch 17/50, Train Loss: 0.0031, Validation Loss: 0.0151, Duration 0:00:00.617711
# Epoch 18/50, Train Loss: 0.0031, Validation Loss: 0.0151, Duration 0:00:00.640256
# Epoch 19/50, Train Loss: 0.0030, Validation Loss: 0.0152, Duration 0:00:00.561196
# Epoch 20/50, Train Loss: 0.0031, Validation Loss: 0.0152, Duration 0:00:00.607630
# Epoch 21/50, Train Loss: 0.0030, Validation Loss: 0.0152, Duration 0:00:00.639770
# Epoch 22/50, Train Loss: 0.0030, Validation Loss: 0.0154, Duration 0:00:00.617900
# Epoch 23/50, Train Loss: 0.0030, Validation Loss: 0.0154, Duration 0:00:00.604894
# Epoch 24/50, Train Loss: 0.0030, Validation Loss: 0.0153, Duration 0:00:00.550408
# Epoch 25/50, Train Loss: 0.0030, Validation Loss: 0.0153, Duration 0:00:00.617511
# Epoch 26/50, Train Loss: 0.0030, Validation Loss: 0.0152, Duration 0:00:00.602911
# Epoch 27/50, Train Loss: 0.0030, Validation Loss: 0.0152, Duration 0:00:00.638629
# Epoch 28/50, Train Loss: 0.0030, Validation Loss: 0.0152, Duration 0:00:00.623037
# Epoch 29/50, Train Loss: 0.0029, Validation Loss: 0.0151, Duration 0:00:00.554355
# Epoch 30/50, Train Loss: 0.0029, Validation Loss: 0.0152, Duration 0:00:00.618094
# Epoch 31/50, Train Loss: 0.0029, Validation Loss: 0.0153, Duration 0:00:00.617419
# Epoch 32/50, Train Loss: 0.0029, Validation Loss: 0.0153, Duration 0:00:00.612924
# Epoch 33/50, Train Loss: 0.0029, Validation Loss: 0.0152, Duration 0:00:00.559672
# Epoch 34/50, Train Loss: 0.0029, Validation Loss: 0.0153, Duration 0:00:00.625973
# Epoch 35/50, Train Loss: 0.0029, Validation Loss: 0.0152, Duration 0:00:00.612301
# Epoch 36/50, Train Loss: 0.0029, Validation Loss: 0.0152, Duration 0:00:00.611985
# Epoch 37/50, Train Loss: 0.0029, Validation Loss: 0.0152, Duration 0:00:00.647807
# Epoch 38/50, Train Loss: 0.0031, Validation Loss: 0.0152, Duration 0:00:00.563782
# Epoch 39/50, Train Loss: 0.0029, Validation Loss: 0.0157, Duration 0:00:00.622953
# Epoch 40/50, Train Loss: 0.0029, Validation Loss: 0.0158, Duration 0:00:00.624244
# Epoch 41/50, Train Loss: 0.0029, Validation Loss: 0.0158, Duration 0:00:00.613019
# Epoch 42/50, Train Loss: 0.0029, Validation Loss: 0.0157, Duration 0:00:00.614025
# Epoch 43/50, Train Loss: 0.0029, Validation Loss: 0.0156, Duration 0:00:00.576692
# Epoch 44/50, Train Loss: 0.0028, Validation Loss: 0.0156, Duration 0:00:00.616050
# Epoch 45/50, Train Loss: 0.0028, Validation Loss: 0.0155, Duration 0:00:00.613400
# Epoch 46/50, Train Loss: 0.0028, Validation Loss: 0.0155, Duration 0:00:00.644737
# Epoch 47/50, Train Loss: 0.0028, Validation Loss: 0.0155, Duration 0:00:00.615252
# Epoch 48/50, Train Loss: 0.0028, Validation Loss: 0.0155, Duration 0:00:00.568638
# Epoch 49/50, Train Loss: 0.0027, Validation Loss: 0.0155, Duration 0:00:00.626723
# Epoch 50/50, Train Loss: 0.0027, Validation Loss: 0.0155, Duration 0:00:00.615976
# Fold 4, final train loss: 0.00274, final train loss: 0.01549
# Epoch 1/50, Train Loss: 0.0028, Validation Loss: 0.0117, Duration 0:00:00.617066
# Epoch 2/50, Train Loss: 0.0028, Validation Loss: 0.0117, Duration 0:00:00.642048
# Epoch 3/50, Train Loss: 0.0028, Validation Loss: 0.0118, Duration 0:00:00.559951
# Epoch 4/50, Train Loss: 0.0028, Validation Loss: 0.0119, Duration 0:00:00.617855
# Epoch 5/50, Train Loss: 0.0028, Validation Loss: 0.0120, Duration 0:00:00.621056
# Epoch 6/50, Train Loss: 0.0027, Validation Loss: 0.0120, Duration 0:00:00.604139
# Epoch 7/50, Train Loss: 0.0027, Validation Loss: 0.0121, Duration 0:00:00.590712
# Epoch 8/50, Train Loss: 0.0027, Validation Loss: 0.0121, Duration 0:00:00.628316
# Epoch 9/50, Train Loss: 0.0027, Validation Loss: 0.0122, Duration 0:00:00.608926
# Epoch 10/50, Train Loss: 0.0027, Validation Loss: 0.0122, Duration 0:00:00.612406
# Epoch 11/50, Train Loss: 0.0027, Validation Loss: 0.0123, Duration 0:00:00.619765
# Epoch 12/50, Train Loss: 0.0027, Validation Loss: 0.0123, Duration 0:00:00.567510
# Epoch 13/50, Train Loss: 0.0027, Validation Loss: 0.0124, Duration 0:00:00.615470
# Epoch 14/50, Train Loss: 0.0026, Validation Loss: 0.0125, Duration 0:00:00.620223
# Epoch 15/50, Train Loss: 0.0026, Validation Loss: 0.0125, Duration 0:00:00.603271
# Epoch 16/50, Train Loss: 0.0026, Validation Loss: 0.0125, Duration 0:00:00.613583
# Epoch 17/50, Train Loss: 0.0027, Validation Loss: 0.0126, Duration 0:00:00.587553
# Epoch 18/50, Train Loss: 0.0026, Validation Loss: 0.0127, Duration 0:00:00.610906
# Epoch 19/50, Train Loss: 0.0026, Validation Loss: 0.0128, Duration 0:00:00.626098
# Epoch 20/50, Train Loss: 0.0026, Validation Loss: 0.0128, Duration 0:00:00.608396
# Epoch 21/50, Train Loss: 0.0026, Validation Loss: 0.0127, Duration 0:00:00.622974
# Epoch 22/50, Train Loss: 0.0026, Validation Loss: 0.0128, Duration 0:00:00.561539
# Epoch 23/50, Train Loss: 0.0026, Validation Loss: 0.0128, Duration 0:00:00.636720
# Epoch 24/50, Train Loss: 0.0030, Validation Loss: 0.0130, Duration 0:00:00.603873
# Epoch 25/50, Train Loss: 0.0026, Validation Loss: 0.0131, Duration 0:00:00.648309
# Epoch 26/50, Train Loss: 0.0026, Validation Loss: 0.0131, Duration 0:00:00.612412
# Epoch 27/50, Train Loss: 0.0025, Validation Loss: 0.0132, Duration 0:00:00.561512
# Epoch 28/50, Train Loss: 0.0025, Validation Loss: 0.0132, Duration 0:00:00.624544
# Epoch 29/50, Train Loss: 0.0025, Validation Loss: 0.0131, Duration 0:00:00.605547
# Epoch 30/50, Train Loss: 0.0025, Validation Loss: 0.0132, Duration 0:00:00.622355
# Epoch 31/50, Train Loss: 0.0025, Validation Loss: 0.0132, Duration 0:00:00.551011
# Epoch 32/50, Train Loss: 0.0025, Validation Loss: 0.0132, Duration 0:00:00.604895
# Epoch 33/50, Train Loss: 0.0025, Validation Loss: 0.0133, Duration 0:00:00.624061
# Epoch 34/50, Train Loss: 0.0025, Validation Loss: 0.0133, Duration 0:00:00.608456
# Epoch 35/50, Train Loss: 0.0025, Validation Loss: 0.0133, Duration 0:00:00.609365
# Epoch 36/50, Train Loss: 0.0024, Validation Loss: 0.0134, Duration 0:00:00.577815
# Epoch 37/50, Train Loss: 0.0024, Validation Loss: 0.0134, Duration 0:00:00.615423
# Epoch 38/50, Train Loss: 0.0024, Validation Loss: 0.0134, Duration 0:00:00.621264
# Epoch 39/50, Train Loss: 0.0024, Validation Loss: 0.0134, Duration 0:00:00.626129
# Epoch 40/50, Train Loss: 0.0024, Validation Loss: 0.0134, Duration 0:00:00.627257
# Epoch 41/50, Train Loss: 0.0024, Validation Loss: 0.0135, Duration 0:00:00.582434
# Epoch 42/50, Train Loss: 0.0024, Validation Loss: 0.0134, Duration 0:00:00.606664
# Epoch 43/50, Train Loss: 0.0023, Validation Loss: 0.0135, Duration 0:00:00.614447
# Epoch 44/50, Train Loss: 0.0023, Validation Loss: 0.0135, Duration 0:00:00.615023
# Epoch 45/50, Train Loss: 0.0023, Validation Loss: 0.0136, Duration 0:00:00.612488
# Epoch 46/50, Train Loss: 0.0023, Validation Loss: 0.0136, Duration 0:00:00.569835
# Epoch 47/50, Train Loss: 0.0023, Validation Loss: 0.0136, Duration 0:00:00.646859
# Epoch 48/50, Train Loss: 0.0023, Validation Loss: 0.0137, Duration 0:00:00.611439
# Epoch 49/50, Train Loss: 0.0023, Validation Loss: 0.0138, Duration 0:00:00.616312
# Epoch 50/50, Train Loss: 0.0023, Validation Loss: 0.0138, Duration 0:00:00.620356
# Fold 5, final train loss: 0.00229, final train loss: 0.01377
# Epoch 1/50, Train Loss: 0.0024, Validation Loss: 0.0085, Duration 0:00:00.570115
# Epoch 2/50, Train Loss: 0.0023, Validation Loss: 0.0085, Duration 0:00:00.621929
# Epoch 3/50, Train Loss: 0.0023, Validation Loss: 0.0086, Duration 0:00:00.615579
# Epoch 4/50, Train Loss: 0.0023, Validation Loss: 0.0087, Duration 0:00:00.631239
# Epoch 5/50, Train Loss: 0.0023, Validation Loss: 0.0088, Duration 0:00:00.563330
# Epoch 6/50, Train Loss: 0.0023, Validation Loss: 0.0089, Duration 0:00:00.624519
# Epoch 7/50, Train Loss: 0.0023, Validation Loss: 0.0090, Duration 0:00:00.662031
# Epoch 8/50, Train Loss: 0.0023, Validation Loss: 0.0091, Duration 0:00:00.629585
# Epoch 9/50, Train Loss: 0.0023, Validation Loss: 0.0093, Duration 0:00:00.619901
# Epoch 10/50, Train Loss: 0.0023, Validation Loss: 0.0094, Duration 0:00:00.551309
# Epoch 11/50, Train Loss: 0.0023, Validation Loss: 0.0095, Duration 0:00:00.612189
# Epoch 12/50, Train Loss: 0.0023, Validation Loss: 0.0096, Duration 0:00:00.616588
# Epoch 13/50, Train Loss: 0.0023, Validation Loss: 0.0096, Duration 0:00:00.601845
# Epoch 14/50, Train Loss: 0.0022, Validation Loss: 0.0097, Duration 0:00:00.609420
# Epoch 15/50, Train Loss: 0.0022, Validation Loss: 0.0097, Duration 0:00:00.551578
# Epoch 16/50, Train Loss: 0.0022, Validation Loss: 0.0097, Duration 0:00:00.627715
# Epoch 17/50, Train Loss: 0.0022, Validation Loss: 0.0097, Duration 0:00:00.646498
# Epoch 18/50, Train Loss: 0.0022, Validation Loss: 0.0098, Duration 0:00:00.615233
# Epoch 19/50, Train Loss: 0.0022, Validation Loss: 0.0100, Duration 0:00:00.625411
# Epoch 20/50, Train Loss: 0.0022, Validation Loss: 0.0101, Duration 0:00:00.551378
# Epoch 21/50, Train Loss: 0.0022, Validation Loss: 0.0102, Duration 0:00:00.616791
# Epoch 22/50, Train Loss: 0.0022, Validation Loss: 0.0102, Duration 0:00:00.625146
# Epoch 23/50, Train Loss: 0.0021, Validation Loss: 0.0102, Duration 0:00:00.618738
# Epoch 24/50, Train Loss: 0.0021, Validation Loss: 0.0102, Duration 0:00:00.602878
# Epoch 25/50, Train Loss: 0.0021, Validation Loss: 0.0102, Duration 0:00:00.557783
# Epoch 26/50, Train Loss: 0.0021, Validation Loss: 0.0103, Duration 0:00:00.615372
# Epoch 27/50, Train Loss: 0.0021, Validation Loss: 0.0103, Duration 0:00:00.613252
# Epoch 28/50, Train Loss: 0.0020, Validation Loss: 0.0104, Duration 0:00:00.619368
# Epoch 29/50, Train Loss: 0.0020, Validation Loss: 0.0104, Duration 0:00:00.571224
# Epoch 30/50, Train Loss: 0.0020, Validation Loss: 0.0104, Duration 0:00:00.615896
# Epoch 31/50, Train Loss: 0.0020, Validation Loss: 0.0105, Duration 0:00:00.630323
# Epoch 32/50, Train Loss: 0.0020, Validation Loss: 0.0105, Duration 0:00:00.613099
# Epoch 33/50, Train Loss: 0.0020, Validation Loss: 0.0105, Duration 0:00:00.608023
# Epoch 34/50, Train Loss: 0.0020, Validation Loss: 0.0105, Duration 0:00:00.554565
# Epoch 35/50, Train Loss: 0.0020, Validation Loss: 0.0106, Duration 0:00:00.609012
# Epoch 36/50, Train Loss: 0.0020, Validation Loss: 0.0106, Duration 0:00:00.614497
# Epoch 37/50, Train Loss: 0.0020, Validation Loss: 0.0107, Duration 0:00:00.629342
# Epoch 38/50, Train Loss: 0.0020, Validation Loss: 0.0108, Duration 0:00:00.604076
# Epoch 39/50, Train Loss: 0.0020, Validation Loss: 0.0108, Duration 0:00:00.559523
# Epoch 40/50, Train Loss: 0.0019, Validation Loss: 0.0109, Duration 0:00:00.650286
# Epoch 41/50, Train Loss: 0.0019, Validation Loss: 0.0109, Duration 0:00:00.619551
# Epoch 42/50, Train Loss: 0.0019, Validation Loss: 0.0109, Duration 0:00:00.631169
# Epoch 43/50, Train Loss: 0.0019, Validation Loss: 0.0109, Duration 0:00:00.617277
# Epoch 44/50, Train Loss: 0.0019, Validation Loss: 0.0110, Duration 0:00:00.561602
# Epoch 45/50, Train Loss: 0.0019, Validation Loss: 0.0111, Duration 0:00:00.607541
# Epoch 46/50, Train Loss: 0.0019, Validation Loss: 0.0111, Duration 0:00:00.612728
# Epoch 47/50, Train Loss: 0.0019, Validation Loss: 0.0111, Duration 0:00:00.634985
# Epoch 48/50, Train Loss: 0.0019, Validation Loss: 0.0112, Duration 0:00:00.605686
# Epoch 49/50, Train Loss: 0.0019, Validation Loss: 0.0113, Duration 0:00:00.569975
# Epoch 50/50, Train Loss: 0.0019, Validation Loss: 0.0114, Duration 0:00:00.626491
# Fold 6, final train loss: 0.00187, final train loss: 0.01141
# Epoch 1/50, Train Loss: 0.0020, Validation Loss: 0.0060, Duration 0:00:00.638231
# Epoch 2/50, Train Loss: 0.0019, Validation Loss: 0.0059, Duration 0:00:00.612902
# Epoch 3/50, Train Loss: 0.0020, Validation Loss: 0.0060, Duration 0:00:00.585707
# Epoch 4/50, Train Loss: 0.0019, Validation Loss: 0.0062, Duration 0:00:00.626570
# Epoch 5/50, Train Loss: 0.0019, Validation Loss: 0.0063, Duration 0:00:00.642549
# Epoch 6/50, Train Loss: 0.0019, Validation Loss: 0.0064, Duration 0:00:00.604434
# Epoch 7/50, Train Loss: 0.0019, Validation Loss: 0.0064, Duration 0:00:00.623933
# Epoch 8/50, Train Loss: 0.0019, Validation Loss: 0.0064, Duration 0:00:00.558652
# Epoch 9/50, Train Loss: 0.0018, Validation Loss: 0.0064, Duration 0:00:00.648579
# Epoch 10/50, Train Loss: 0.0018, Validation Loss: 0.0065, Duration 0:00:00.633819
# Epoch 11/50, Train Loss: 0.0018, Validation Loss: 0.0065, Duration 0:00:00.622271
# Epoch 12/50, Train Loss: 0.0018, Validation Loss: 0.0067, Duration 0:00:00.607932
# Epoch 13/50, Train Loss: 0.0018, Validation Loss: 0.0068, Duration 0:00:00.560498
# Epoch 14/50, Train Loss: 0.0021, Validation Loss: 0.0071, Duration 0:00:00.619149
# Epoch 15/50, Train Loss: 0.0019, Validation Loss: 0.0074, Duration 0:00:00.623818
# Epoch 16/50, Train Loss: 0.0019, Validation Loss: 0.0075, Duration 0:00:00.619742
# Epoch 17/50, Train Loss: 0.0018, Validation Loss: 0.0075, Duration 0:00:00.604585
# Epoch 18/50, Train Loss: 0.0018, Validation Loss: 0.0074, Duration 0:00:00.565538
# Epoch 19/50, Train Loss: 0.0018, Validation Loss: 0.0074, Duration 0:00:00.624355
# Epoch 20/50, Train Loss: 0.0018, Validation Loss: 0.0074, Duration 0:00:00.625955
# Epoch 21/50, Train Loss: 0.0018, Validation Loss: 0.0075, Duration 0:00:00.642206
# Epoch 22/50, Train Loss: 0.0018, Validation Loss: 0.0076, Duration 0:00:00.650096
# Epoch 23/50, Train Loss: 0.0018, Validation Loss: 0.0077, Duration 0:00:00.568699
# Epoch 24/50, Train Loss: 0.0017, Validation Loss: 0.0077, Duration 0:00:00.641119
# Epoch 25/50, Train Loss: 0.0017, Validation Loss: 0.0077, Duration 0:00:00.605781
# Epoch 26/50, Train Loss: 0.0017, Validation Loss: 0.0077, Duration 0:00:00.625176
# Epoch 27/50, Train Loss: 0.0017, Validation Loss: 0.0078, Duration 0:00:00.585475
# Epoch 28/50, Train Loss: 0.0017, Validation Loss: 0.0078, Duration 0:00:00.615385
# Epoch 29/50, Train Loss: 0.0017, Validation Loss: 0.0079, Duration 0:00:00.617556
# Epoch 30/50, Train Loss: 0.0017, Validation Loss: 0.0079, Duration 0:00:00.627890
# Epoch 31/50, Train Loss: 0.0017, Validation Loss: 0.0080, Duration 0:00:00.620842
# Epoch 32/50, Train Loss: 0.0017, Validation Loss: 0.0080, Duration 0:00:00.554052
# Epoch 33/50, Train Loss: 0.0017, Validation Loss: 0.0080, Duration 0:00:00.623043
# Epoch 34/50, Train Loss: 0.0016, Validation Loss: 0.0081, Duration 0:00:00.641296
# Epoch 35/50, Train Loss: 0.0016, Validation Loss: 0.0082, Duration 0:00:00.633800
# Epoch 36/50, Train Loss: 0.0016, Validation Loss: 0.0082, Duration 0:00:00.630004
# Epoch 37/50, Train Loss: 0.0016, Validation Loss: 0.0083, Duration 0:00:00.614897
# Epoch 38/50, Train Loss: 0.0016, Validation Loss: 0.0083, Duration 0:00:00.634899
# Epoch 39/50, Train Loss: 0.0016, Validation Loss: 0.0084, Duration 0:00:00.612289
# Epoch 40/50, Train Loss: 0.0016, Validation Loss: 0.0085, Duration 0:00:00.617285
# Epoch 41/50, Train Loss: 0.0016, Validation Loss: 0.0085, Duration 0:00:00.631540
# Epoch 42/50, Train Loss: 0.0016, Validation Loss: 0.0086, Duration 0:00:00.594259
# Epoch 43/50, Train Loss: 0.0016, Validation Loss: 0.0086, Duration 0:00:00.628678
# Epoch 44/50, Train Loss: 0.0016, Validation Loss: 0.0087, Duration 0:00:00.612331
# Epoch 45/50, Train Loss: 0.0015, Validation Loss: 0.0087, Duration 0:00:00.627928
# Epoch 46/50, Train Loss: 0.0018, Validation Loss: 0.0088, Duration 0:00:00.604840
# Epoch 47/50, Train Loss: 0.0016, Validation Loss: 0.0090, Duration 0:00:00.579597
# Epoch 48/50, Train Loss: 0.0016, Validation Loss: 0.0091, Duration 0:00:00.607760
# Epoch 49/50, Train Loss: 0.0016, Validation Loss: 0.0092, Duration 0:00:00.623204
# Epoch 50/50, Train Loss: 0.0015, Validation Loss: 0.0092, Duration 0:00:00.605520
# Fold 7, final train loss: 0.00154, final train loss: 0.00920
# Epoch 1/50, Train Loss: 0.0016, Validation Loss: 0.0041, Duration 0:00:00.566339
# Epoch 2/50, Train Loss: 0.0016, Validation Loss: 0.0041, Duration 0:00:00.655642
# Epoch 3/50, Train Loss: 0.0016, Validation Loss: 0.0042, Duration 0:00:00.623047
# Epoch 4/50, Train Loss: 0.0016, Validation Loss: 0.0043, Duration 0:00:00.605388
# Epoch 5/50, Train Loss: 0.0016, Validation Loss: 0.0043, Duration 0:00:00.602437
# Epoch 6/50, Train Loss: 0.0016, Validation Loss: 0.0044, Duration 0:00:00.572439
# Epoch 7/50, Train Loss: 0.0015, Validation Loss: 0.0045, Duration 0:00:00.620418
# Epoch 8/50, Train Loss: 0.0015, Validation Loss: 0.0045, Duration 0:00:00.618811
# Epoch 9/50, Train Loss: 0.0015, Validation Loss: 0.0046, Duration 0:00:00.603877
# Epoch 10/50, Train Loss: 0.0015, Validation Loss: 0.0046, Duration 0:00:00.627281
# Epoch 11/50, Train Loss: 0.0015, Validation Loss: 0.0047, Duration 0:00:00.560812
# Epoch 12/50, Train Loss: 0.0015, Validation Loss: 0.0047, Duration 0:00:00.632012
# Epoch 13/50, Train Loss: 0.0015, Validation Loss: 0.0047, Duration 0:00:00.622912
# Epoch 14/50, Train Loss: 0.0015, Validation Loss: 0.0048, Duration 0:00:00.627662
# Epoch 15/50, Train Loss: 0.0014, Validation Loss: 0.0048, Duration 0:00:00.624387
# Epoch 16/50, Train Loss: 0.0014, Validation Loss: 0.0048, Duration 0:00:00.564862
# Epoch 17/50, Train Loss: 0.0015, Validation Loss: 0.0049, Duration 0:00:00.615649
# Epoch 18/50, Train Loss: 0.0014, Validation Loss: 0.0051, Duration 0:00:00.645799
# Epoch 19/50, Train Loss: 0.0014, Validation Loss: 0.0052, Duration 0:00:00.612517
# Epoch 20/50, Train Loss: 0.0014, Validation Loss: 0.0052, Duration 0:00:00.621505
# Epoch 21/50, Train Loss: 0.0014, Validation Loss: 0.0053, Duration 0:00:00.571664
# Epoch 22/50, Train Loss: 0.0014, Validation Loss: 0.0053, Duration 0:00:00.603628
# Epoch 23/50, Train Loss: 0.0014, Validation Loss: 0.0054, Duration 0:00:00.618898
# Epoch 24/50, Train Loss: 0.0014, Validation Loss: 0.0054, Duration 0:00:00.604592
# Epoch 25/50, Train Loss: 0.0014, Validation Loss: 0.0054, Duration 0:00:00.552287
# Epoch 26/50, Train Loss: 0.0014, Validation Loss: 0.0055, Duration 0:00:00.619035
# Epoch 27/50, Train Loss: 0.0014, Validation Loss: 0.0055, Duration 0:00:00.623151
# Epoch 28/50, Train Loss: 0.0013, Validation Loss: 0.0055, Duration 0:00:00.617166
# Epoch 29/50, Train Loss: 0.0014, Validation Loss: 0.0056, Duration 0:00:00.616273
# Epoch 30/50, Train Loss: 0.0013, Validation Loss: 0.0056, Duration 0:00:00.550829
# Epoch 31/50, Train Loss: 0.0013, Validation Loss: 0.0057, Duration 0:00:00.614842
# Epoch 32/50, Train Loss: 0.0013, Validation Loss: 0.0058, Duration 0:00:00.613584
# Epoch 33/50, Train Loss: 0.0013, Validation Loss: 0.0058, Duration 0:00:00.616317
# Epoch 34/50, Train Loss: 0.0013, Validation Loss: 0.0058, Duration 0:00:00.608869
# Epoch 35/50, Train Loss: 0.0013, Validation Loss: 0.0058, Duration 0:00:00.574224
# Epoch 36/50, Train Loss: 0.0013, Validation Loss: 0.0059, Duration 0:00:00.640543
# Epoch 37/50, Train Loss: 0.0013, Validation Loss: 0.0059, Duration 0:00:00.619455
# Epoch 38/50, Train Loss: 0.0013, Validation Loss: 0.0060, Duration 0:00:00.625276
# Epoch 39/50, Train Loss: 0.0013, Validation Loss: 0.0061, Duration 0:00:00.607058
# Epoch 40/50, Train Loss: 0.0012, Validation Loss: 0.0061, Duration 0:00:00.565231
# Epoch 41/50, Train Loss: 0.0012, Validation Loss: 0.0061, Duration 0:00:00.624404
# Epoch 42/50, Train Loss: 0.0012, Validation Loss: 0.0062, Duration 0:00:00.613664
# Epoch 43/50, Train Loss: 0.0012, Validation Loss: 0.0063, Duration 0:00:00.605172
# Epoch 44/50, Train Loss: 0.0012, Validation Loss: 0.0064, Duration 0:00:00.620866
# Epoch 45/50, Train Loss: 0.0013, Validation Loss: 0.0064, Duration 0:00:00.565747
# Epoch 46/50, Train Loss: 0.0012, Validation Loss: 0.0064, Duration 0:00:00.614339
# Epoch 47/50, Train Loss: 0.0012, Validation Loss: 0.0065, Duration 0:00:00.608878
# Epoch 48/50, Train Loss: 0.0012, Validation Loss: 0.0067, Duration 0:00:00.605915
# Epoch 49/50, Train Loss: 0.0012, Validation Loss: 0.0068, Duration 0:00:00.558095
# Epoch 50/50, Train Loss: 0.0012, Validation Loss: 0.0068, Duration 0:00:00.632372
# Fold 8, final train loss: 0.00121, final train loss: 0.00682
# Epoch 1/50, Train Loss: 0.0013, Validation Loss: 0.0026, Duration 0:00:00.617637
# Epoch 2/50, Train Loss: 0.0013, Validation Loss: 0.0025, Duration 0:00:00.617981
# Epoch 3/50, Train Loss: 0.0013, Validation Loss: 0.0025, Duration 0:00:00.624774
# Epoch 4/50, Train Loss: 0.0013, Validation Loss: 0.0026, Duration 0:00:00.563811
# Epoch 5/50, Train Loss: 0.0012, Validation Loss: 0.0026, Duration 0:00:00.613674
# Epoch 6/50, Train Loss: 0.0013, Validation Loss: 0.0026, Duration 0:00:00.631686
# Epoch 7/50, Train Loss: 0.0012, Validation Loss: 0.0028, Duration 0:00:00.618011
# Epoch 8/50, Train Loss: 0.0012, Validation Loss: 0.0028, Duration 0:00:00.613795
# Epoch 9/50, Train Loss: 0.0012, Validation Loss: 0.0029, Duration 0:00:00.553373
# Epoch 10/50, Train Loss: 0.0012, Validation Loss: 0.0029, Duration 0:00:00.626351
# Epoch 11/50, Train Loss: 0.0012, Validation Loss: 0.0030, Duration 0:00:00.622048
# Epoch 12/50, Train Loss: 0.0012, Validation Loss: 0.0030, Duration 0:00:00.603411
# Epoch 13/50, Train Loss: 0.0012, Validation Loss: 0.0031, Duration 0:00:00.620638
# Epoch 14/50, Train Loss: 0.0012, Validation Loss: 0.0031, Duration 0:00:00.586705
# Epoch 15/50, Train Loss: 0.0012, Validation Loss: 0.0031, Duration 0:00:00.618625
# Epoch 16/50, Train Loss: 0.0012, Validation Loss: 0.0032, Duration 0:00:00.612559
# Epoch 17/50, Train Loss: 0.0012, Validation Loss: 0.0032, Duration 0:00:00.634781
# Epoch 18/50, Train Loss: 0.0012, Validation Loss: 0.0033, Duration 0:00:00.621030
# Epoch 19/50, Train Loss: 0.0011, Validation Loss: 0.0033, Duration 0:00:00.551621
# Epoch 20/50, Train Loss: 0.0011, Validation Loss: 0.0033, Duration 0:00:00.603218
# Epoch 21/50, Train Loss: 0.0011, Validation Loss: 0.0034, Duration 0:00:00.617458
# Epoch 22/50, Train Loss: 0.0011, Validation Loss: 0.0034, Duration 0:00:00.610477
# Epoch 23/50, Train Loss: 0.0011, Validation Loss: 0.0034, Duration 0:00:00.552266
# Epoch 24/50, Train Loss: 0.0011, Validation Loss: 0.0035, Duration 0:00:00.618938
# Epoch 25/50, Train Loss: 0.0011, Validation Loss: 0.0035, Duration 0:00:00.606080
# Epoch 26/50, Train Loss: 0.0011, Validation Loss: 0.0035, Duration 0:00:00.608662
# Epoch 27/50, Train Loss: 0.0011, Validation Loss: 0.0036, Duration 0:00:00.630946
# Epoch 28/50, Train Loss: 0.0011, Validation Loss: 0.0037, Duration 0:00:00.552770
# Epoch 29/50, Train Loss: 0.0011, Validation Loss: 0.0037, Duration 0:00:00.615875
# Epoch 30/50, Train Loss: 0.0011, Validation Loss: 0.0037, Duration 0:00:00.606253
# Epoch 31/50, Train Loss: 0.0010, Validation Loss: 0.0038, Duration 0:00:00.623239
# Epoch 32/50, Train Loss: 0.0011, Validation Loss: 0.0038, Duration 0:00:00.622154
# Epoch 33/50, Train Loss: 0.0010, Validation Loss: 0.0039, Duration 0:00:00.556468
# Epoch 34/50, Train Loss: 0.0010, Validation Loss: 0.0039, Duration 0:00:00.638913
# Epoch 35/50, Train Loss: 0.0011, Validation Loss: 0.0040, Duration 0:00:00.628196
# Epoch 36/50, Train Loss: 0.0010, Validation Loss: 0.0040, Duration 0:00:00.605820
# Epoch 37/50, Train Loss: 0.0010, Validation Loss: 0.0041, Duration 0:00:00.646768
# Epoch 38/50, Train Loss: 0.0010, Validation Loss: 0.0041, Duration 0:00:00.553604
# Epoch 39/50, Train Loss: 0.0010, Validation Loss: 0.0041, Duration 0:00:00.637189
# Epoch 40/50, Train Loss: 0.0010, Validation Loss: 0.0042, Duration 0:00:00.604539
# Epoch 41/50, Train Loss: 0.0010, Validation Loss: 0.0042, Duration 0:00:00.611040
# Epoch 42/50, Train Loss: 0.0010, Validation Loss: 0.0043, Duration 0:00:00.605089
# Epoch 43/50, Train Loss: 0.0010, Validation Loss: 0.0043, Duration 0:00:00.572507
# Epoch 44/50, Train Loss: 0.0010, Validation Loss: 0.0044, Duration 0:00:00.625531
# Epoch 45/50, Train Loss: 0.0010, Validation Loss: 0.0044, Duration 0:00:00.605476
# Epoch 46/50, Train Loss: 0.0010, Validation Loss: 0.0045, Duration 0:00:00.634433
# Epoch 47/50, Train Loss: 0.0010, Validation Loss: 0.0044, Duration 0:00:00.563593
# Epoch 48/50, Train Loss: 0.0010, Validation Loss: 0.0044, Duration 0:00:00.638447
# Epoch 49/50, Train Loss: 0.0010, Validation Loss: 0.0045, Duration 0:00:00.619591
# Epoch 50/50, Train Loss: 0.0010, Validation Loss: 0.0045, Duration 0:00:00.611060
# Fold 9, final train loss: 0.00098, final train loss: 0.00453

# %%
plt.plot(train_losses, label='train loss')
plt.plot(val_losses, label='validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Eval

# %%
test_dataset = MoaDataset(X_test, None, mode='eval')
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)
preds = predict(model, device, test_loader)
# Out:
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1639: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")

# %%
targets = [col for col in train_targets.columns]
sample_submission[targets] = preds
sample_submission.loc[test_features['cp_type']=='ctl_vehicle', targets] = 0
sample_submission.to_csv('submission.csv', index=False)
