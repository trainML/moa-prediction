# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.datasets import make_classification
from sklearn.neighbors import NearestNeighbors
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.mongoexp import MongoTrials
from types import SimpleNamespace

import os
from datetime import datetime
import sys
import time
try:
    from iterstrat.ml_stratifiers import MultilabelStratifiedKFold  # trainML
except:
    sys.path.append("../input/iterative-stratification")  # kaggle
    from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

# %%
BASE_PATH = os.environ.get('TRAINML_DATA_PATH') if os.environ.get('TRAINML_DATA_PATH') else '../input/lish-moa'
BASE_PATH
# Out:
# '/opt/trainml/input'

# %%
train_features = pd.read_csv(f'{BASE_PATH}/train_features.csv')
train_targets = pd.read_csv(f'{BASE_PATH}/train_targets_scored.csv')
test_features = pd.read_csv(f'{BASE_PATH}/test_features.csv')

sample_submission = pd.read_csv(f'{BASE_PATH}/sample_submission.csv')

# %% [markdown]
# ### Data preprocessing

# %%
def preprocess(df):
    df = df.copy()
    df.loc[:, 'cp_type'] = df.loc[:, 'cp_type'].map({'trt_cp': 0, 'ctl_vehicle': 1})
    df.loc[:, 'cp_dose'] = df.loc[:, 'cp_dose'].map({'D1': 0, 'D2': 1})
    del df['sig_id']
    return df

train_data = preprocess(train_features)
test_data = preprocess(test_features)

del train_targets['sig_id']

train_targets = train_targets.loc[train_data['cp_type']==0].reset_index(drop=True)
train_data = train_data.loc[train_data['cp_type']==0].reset_index(drop=True)

# %%
X_original = train_data.values
Y_original = train_targets.values

X_test = test_data.values

# %% [markdown]
# ### Data augmentation helper functions
#
# Currently only doing data oversampling with MLSMOTE algorithm.

# %%
def get_tail_labels(df: pd.DataFrame, ql=[0.03, 1.]) -> list:
    " Find the underepresented targets a.k.a. minority labels. "
    irlbl = df.sum(axis=0)
    irlbl = irlbl[(irlbl > irlbl.quantile(ql[0])) & ((irlbl < irlbl.quantile(ql[1])))]  # Filtering
    irlbl = irlbl.max() / irlbl
    threshold_irlbl = irlbl.median()
    tail_labels = irlbl[irlbl > threshold_irlbl].index.tolist()
    return tail_labels

def get_minority_samples(X: pd.DataFrame, y: pd.DataFrame, ql=[0.03, 1.]):
    " Find minority samples associated with minority labels. "
    tail_labels = get_tail_labels(y, ql=ql)
    index = y[y[tail_labels].apply(lambda x: (x == 1).any(), axis=1)].index.tolist()
    
    X_sub = X[X.index.isin(index)].reset_index(drop = True)
    y_sub = y[y.index.isin(index)].reset_index(drop = True)
    return X_sub, y_sub

def nearest_neighbour(X: pd.DataFrame, neigh) -> list:
    " Find nearest neighbors for each sample in X dataframe. "
    nbs = NearestNeighbors(n_neighbors=neigh, metric='euclidean', algorithm='kd_tree').fit(X)
    euclidean, indices = nbs.kneighbors(X)
    return indices

def MLSMOTE(X, y, n_samples, n_neighbors=5):
    " Generate new samples using MLSMOTE algorithm. "
    indices2 = nearest_neighbour(X, neigh=n_neighbors)
    n = len(indices2)
    new_X = np.zeros((n_samples, X.shape[1]))
    target = np.zeros((n_samples, y.shape[1]))
    for i in range(n_samples):
        reference = random.randint(0, n-1)
        neighbor = random.choice(indices2[reference, 1:])
        all_point = indices2[reference]
        nn_df = y[y.index.isin(all_point)]
        ser = nn_df.sum(axis = 0, skipna = True)
        target[i] = np.array([1 if val > 0 else 0 for val in ser])
        ratio = random.random()
        gap = X.loc[reference,:] - X.loc[neighbor,:]
        new_X[i] = np.array(X.loc[reference,:] + ratio * gap)
    new_X = pd.DataFrame(new_X, columns=X.columns)
    target = pd.DataFrame(target, columns=y.columns)
    return new_X, target

def augment_data(X, y, oversample_args: tuple):
    " Augment feature/targets data (just doing oversampling for now)"
    n_samples, n_neighbors = oversample_args

    X_sub, y_sub = get_minority_samples(X, y)
    X_res, y_res = MLSMOTE(X_sub, y_sub, n_samples, n_neighbors)
    X_augmented = pd.concat([X, X_res])
    y_augmented = pd.concat([y, y_res])
    return X_augmented, y_augmented

# %% [markdown]
# ### Define model + dataset

# %%
class MoaModel(nn.Module):
    def __init__(    
        self,
        n_columns,
        n_targets,
        layer1_outputs,
        layer1_dropout,
        layer2_outputs,
        layer2_dropout,
        layer3_enable,
        layer3_outputs,
        layer3_dropout,
        final_layer_dropout,
    ):
        super(MoaModel, self).__init__()   
        self.batch_norm1 = nn.BatchNorm1d(n_columns)
        self.dropout1 = nn.Dropout(layer1_dropout)
        self.dense1 = nn.utils.weight_norm(nn.Linear(n_columns, layer1_outputs))
        
        self.batch_norm2 = nn.BatchNorm1d(layer1_outputs)
        self.dropout2 = nn.Dropout(layer2_dropout)
        self.dense2 = nn.utils.weight_norm(nn.Linear(layer1_outputs, layer2_outputs))
        
        self.layer3 = layer3_enable
        if self.layer3:
            self.batch_norm3 = nn.BatchNorm1d(layer2_outputs)
            self.dropout3 = nn.Dropout(layer3_dropout)
            self.dense3 = nn.utils.weight_norm(
                nn.Linear(layer2_outputs, layer3_outputs)
            )
            
        final_layer_inputs = layer3_outputs if self.layer3 else layer2_outputs
        self.batch_norm_final = nn.BatchNorm1d(final_layer_inputs)
        self.dropout_final = nn.Dropout(final_layer_dropout)
        self.dense_final = nn.utils.weight_norm(nn.Linear(final_layer_inputs, n_targets))
        
    def forward(self, X):
        X = self.batch_norm1(X)
        X = self.dropout1(X)
        X = F.relu(self.dense1(X))
        
        X = self.batch_norm2(X)
        X = self.dropout2(X)
        X = F.relu(self.dense2(X))
        
        if self.layer3:
            X = self.batch_norm3(X)
            X = self.dropout3(X)
            X = F.relu(self.dense3(X))
            
        X = self.batch_norm_final(X)
        X = self.dropout_final(X)
        X = F.sigmoid(self.dense_final(X))
        
        return X
    
    def _load_from_file(self, file):
        self.load_state_dict(torch.load(file))
        
    def save(self, file):
        torch.save(self.state_dict(), file)
        
def batch_gd(model, device, criterion, optimizer, train_loader, val_loader, epochs):
    train_losses = np.zeros(epochs)
    val_losses = np.zeros(epochs)
    for it in range(epochs):
        t0 = datetime.now()

        model.train()
        train_loss = []
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)

            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, targets)

            loss.backward()
            optimizer.step()

            train_loss.append(loss.item() / len(train_loader))

        train_loss = np.mean(train_loss)

        model.eval()
        val_loss = []
        for inputs, targets in val_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            val_loss.append(loss.item() / len(val_loader))
        val_loss = np.mean(val_loss)

        train_losses[it] = train_loss
        val_losses[it] = val_loss

        dt = datetime.now() - t0
        print(
            f"Epoch {it+1}/{epochs}, Train Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}, Duration {dt}"
        )

    return train_losses, val_losses

# %%
class MoaDataset(Dataset):
    def __init__(self, features, targets, mode="train"):
        self.mode = mode
        self.data = features
        if mode == "train":
            self.targets = targets

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        if self.mode == "train":
            return torch.FloatTensor(self.data[idx]), torch.FloatTensor(
                self.targets[idx]
            )
        elif self.mode == "eval":
            return torch.FloatTensor(self.data[idx]), 0

# %% [markdown]
# ### Helper functions for hyperopt's `objective`

# %%
def augment_data(X, y, n_samples, n_neighbors):
    """
    Augment feature/targets data with oversampling (using MLSMOTE algorithm)
    Parameters for hyperopt search space:
        n_samples - # of data points to add for underrepresented labels
        n_neighbors - used for MLSMOTE algorithm.
    """
    X_sub, y_sub = get_minority_samples(X, y)
    X_res, y_res = MLSMOTE(X_sub, y_sub, n_samples, n_neighbors)
    X_augmented = pd.concat([X, X_res])
    y_augmented = pd.concat([y, y_res])
    return X_augmented, y_augmented

# Lines to replicate in hyperopt:
# train_data_augmented, train_targets_augmented = augment_data(train_data, train_targets, 1000, 5)
# X = train_data_augmented.values
# Y = train_targets_augmented.values

def make_model(
        n_columns,
        n_targets,
        layer1_outputs,
        layer1_dropout,
        layer2_outputs,
        layer2_dropout,
        layer3_enable,
        layer3_outputs,
        layer3_dropout,
        final_layer_dropout,
        device
    ):
    """
    Make a 2 or 3 layer neural network with specified outputs and dropout per layer.
    These 8 function parameters are exposed for hyperopt search space.
    """
    model = MoaModel(n_columns, n_targets, layer1_outputs, layer1_dropout, layer2_outputs,
                   layer2_dropout, layer3_enable, layer3_outputs, layer3_dropout, final_layer_dropout)
    model.to(device)
    return model

# Lines to replicate in hyperopt:
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model = make_model(n_columns=train_data.shape[1], <....>, n_targets=206, device)

def train(model, device, X, Y, n_splits, batch_size, epochs):
    """
    Run model training. Batch size, # splits for k-fold iteration, and number of epochs
    are exposed for hyperopt search space.
    Returns tuple of (train_losses, val_losses).
    """
    kfold = MultilabelStratifiedKFold(n_splits=n_splits, random_state=42, shuffle=True)

    criterion = nn.BCELoss()
    optimizer = torch.optim.Adam(model.parameters()) # TODO parameterize?

    train_losses = np.array([])
    val_losses = np.array([])

    for n, (tr, te) in enumerate(kfold.split(X, Y)):
        X_train, X_val = X[tr], X[te]
        y_train, y_val = Y[tr], Y[te]

        train_dataset = MoaDataset(X_train, y_train)
        val_dataset = MoaDataset(X_val, y_val)
        train_loader = torch.utils.data.DataLoader(
            dataset=train_dataset, batch_size=batch_size, shuffle=True
        )
        val_loader = torch.utils.data.DataLoader(
            dataset=val_dataset, batch_size=batch_size, shuffle=False
        )
        split_train_losses, split_val_losses = batch_gd(
            model, device, criterion, optimizer, train_loader, val_loader, epochs
        )
        print(
            f"Fold {n+1}, final train loss: {split_train_losses[epochs-1]:5.5f}, final train loss: {split_val_losses[epochs-1]:5.5f}"
        )
        train_losses = np.concatenate((train_losses, split_train_losses))
        val_losses = np.concatenate((val_losses, split_val_losses))

    model.save("latest_model")
    return train_losses, val_losses

# Lines to replicate in hyperopt:
# train_losses, val_losses = train_model(model, device, X, Y, n_splits=10, batch_size=4096, epochs=50)

# %% [markdown]
# ### Hyperopt config - objective function and search space

# %%
def objective(space):
    args = SimpleNamespace(**space)
    
    # Augment data
    train_data, train_targets = augment_data(args.train_data, args.train_targets, args.n_samples, args.n_neighbors)
    X = train_data.values
    Y = train_targets.values
    
    # Build model architecture
    device = args.device
    model = make_model(
                args.n_columns,
                args.n_targets,
                args.layer1_outputs,
                args.layer1_dropout,
                args.layer2_outputs,
                args.layer2_dropout,
                args.layer3_enable,
                args.layer3_outputs,
                args.layer3_dropout,
                args.final_layer_dropout,
                args.device
    )
    
    # Train model
    train_losses, val_losses = train(model, device, X, Y, args.n_splits, args.batch_size, args.epochs)

    return {
        'loss': train_losses[-1],
        'train_losses': train_losses,
        'val_losses': val_losses,
        'model_result': model,
        'status': STATUS_OK,
        'eval_time': time.time()
    }
    

space = {
    # general
    'device': torch.device("cuda" if torch.cuda.is_available() else "cpu"),
    'train_data': train_data,
    'train_targets': train_targets,
    
    # data augmentation
    'n_samples': hp.randint('n_samples', 5000),
    'n_neighbors': 3 + hp.randint('n_neighbors', 10),
    
    # model architecture
    # TODO: add optimizer
    'n_columns': train_data.shape[1],
    'n_targets': train_targets.shape[1],
    'layer1_outputs': 256 + hp.randint('layer1_outputs', 4096),
    'layer1_dropout': hp.uniform('layer1_dropout', 0, 1),
    'layer2_outputs': 256 + hp.randint('layer2_outputs', 4096),
    'layer2_dropout': hp.uniform('layer2_dropout', 0, 1),
    'layer3_enable': hp.choice('layer3_enable', [True, False]),
    'layer3_outputs': 256 + hp.randint('layer3_outputs', 4096),
    'layer3_dropout': hp.uniform('layer3_dropout', 0, 1),
    'final_layer_dropout': hp.uniform('final_layer_dropout', 0, 1),
    
    # cross-validation
    'n_splits': 5 + hp.randint('n_splits', 10),
    'batch_size': 1 + hp.randint('batch_size', 8192),
    'epochs': 1 + hp.randint('epochs', 100)
}

# %% [markdown]
# ### Run model training via hyperopt

# %%
trials = Trials() # TODO: Make it MongoTrials
best = fmin(
    objective,
    space=space,
    algo=tpe.suggest,
    max_evals=100,
    trials=trials
    # max_queue_len=4 <-- what again is this used for? multiple workers?
)
# Out:
#   0%|          | 0/100 [00:00<?, ?trial/s, best loss=?]
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass shuffle=True, random_state=42 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1639: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Epoch 1/60, Train Loss: 0.1989, Validation Loss: 0.6915, Duration 0:00:00.665737
# Epoch 2/60, Train Loss: 0.1925, Validation Loss: 0.7163, Duration 0:00:00.661304
# Epoch 3/60, Train Loss: 0.1875, Validation Loss: 0.7525, Duration 0:00:00.655368
# Epoch 4/60, Train Loss: 0.1823, Validation Loss: 0.7847, Duration 0:00:00.612659
# Epoch 5/60, Train Loss: 0.1765, Validation Loss: 0.8079, Duration 0:00:00.657323
# Epoch 6/60, Train Loss: 0.1682, Validation Loss: 0.8207, Duration 0:00:00.673271
# Epoch 7/60, Train Loss: 0.1603, Validation Loss: 0.8297, Duration 0:00:00.664011
# Epoch 8/60, Train Loss: 0.1492, Validation Loss: 0.8265, Duration 0:00:00.672214
# Epoch 9/60, Train Loss: 0.1373, Validation Loss: 0.8196, Duration 0:00:00.681350
# Epoch 10/60, Train Loss: 0.1249, Validation Loss: 0.8063, Duration 0:00:00.677060
# Epoch 11/60, Train Loss: 0.1126, Validation Loss: 0.7762, Duration 0:00:00.696036
# Epoch 12/60, Train Loss: 0.0980, Validation Loss: 0.7568, Duration 0:00:00.653447
# Epoch 13/60, Train Loss: 0.0897, Validation Loss: 0.7715, Duration 0:00:00.687663
# Epoch 14/60, Train Loss: 0.0783, Validation Loss: 0.7111, Duration 0:00:00.680574
# Epoch 15/60, Train Loss: 0.0681, Validation Loss: 0.7663, Duration 0:00:00.663187
# Epoch 16/60, Train Loss: 0.0643, Validation Loss: 0.8312, Duration 0:00:00.579774
# Epoch 17/60, Train Loss: 0.0564, Validation Loss: 0.7451, Duration 0:00:00.672845
# Epoch 18/60, Train Loss: 0.0503, Validation Loss: 0.6793, Duration 0:00:00.653565
# Epoch 19/60, Train Loss: 0.0464, Validation Loss: 0.7806, Duration 0:00:00.655300
# Epoch 20/60, Train Loss: 0.0418, Validation Loss: 0.8446, Duration 0:00:00.706945
# Epoch 21/60, Train Loss: 0.0387, Validation Loss: 0.7016, Duration 0:00:00.652248
# Epoch 22/60, Train Loss: 0.0367, Validation Loss: 0.6544, Duration 0:00:00.702653
# Epoch 23/60, Train Loss: 0.0342, Validation Loss: 0.6673, Duration 0:00:00.658689
# Epoch 24/60, Train Loss: 0.0352, Validation Loss: 0.7507, Duration 0:00:00.699602
# Epoch 25/60, Train Loss: 0.0302, Validation Loss: 0.7548, Duration 0:00:00.653686
# Epoch 26/60, Train Loss: 0.0305, Validation Loss: 0.7356, Duration 0:00:00.677100
# Epoch 27/60, Train Loss: 0.0276, Validation Loss: 0.6420, Duration 0:00:00.584873
# Epoch 28/60, Train Loss: 0.0253, Validation Loss: 0.6566, Duration 0:00:00.650109
# Epoch 29/60, Train Loss: 0.0238, Validation Loss: 0.7105, Duration 0:00:00.689786
# Epoch 30/60, Train Loss: 0.0230, Validation Loss: 0.7108, Duration 0:00:00.654344
# Epoch 31/60, Train Loss: 0.0234, Validation Loss: 0.6641, Duration 0:00:00.684123
# Epoch 32/60, Train Loss: 0.0212, Validation Loss: 0.6050, Duration 0:00:00.650814
# Epoch 33/60, Train Loss: 0.0231, Validation Loss: 0.5797, Duration 0:00:00.714396
# Epoch 34/60, Train Loss: 0.0199, Validation Loss: 0.5270, Duration 0:00:00.657189
# Epoch 35/60, Train Loss: 0.0200, Validation Loss: 0.4742, Duration 0:00:00.653712
# Epoch 36/60, Train Loss: 0.0190, Validation Loss: 0.4643, Duration 0:00:00.685414
# Epoch 37/60, Train Loss: 0.0185, Validation Loss: 0.4978, Duration 0:00:00.691805
# Epoch 38/60, Train Loss: 0.0180, Validation Loss: 0.5599, Duration 0:00:00.592698
# Epoch 39/60, Train Loss: 0.0179, Validation Loss: 0.5187, Duration 0:00:00.659916
# Epoch 40/60, Train Loss: 0.0171, Validation Loss: 0.4503, Duration 0:00:00.661392
# Epoch 41/60, Train Loss: 0.0175, Validation Loss: 0.3677, Duration 0:00:00.658189
# Epoch 42/60, Train Loss: 0.0166, Validation Loss: 0.3296, Duration 0:00:00.688343
# Epoch 43/60, Train Loss: 0.0188, Validation Loss: 0.3373, Duration 0:00:00.677245
# Epoch 44/60, Train Loss: 0.0161, Validation Loss: 0.3455, Duration 0:00:00.676464
# Epoch 45/60, Train Loss: 0.0155, Validation Loss: 0.3910, Duration 0:00:00.653933
# Epoch 46/60, Train Loss: 0.0160, Validation Loss: 0.3724, Duration 0:00:00.664110
# Epoch 47/60, Train Loss: 0.0153, Validation Loss: 0.3150, Duration 0:00:00.672067
# Epoch 48/60, Train Loss: 0.0152, Validation Loss: 0.2759, Duration 0:00:00.676090
# Epoch 49/60, Train Loss: 0.0149, Validation Loss: 0.2692, Duration 0:00:00.667679
# Epoch 50/60, Train Loss: 0.0148, Validation Loss: 0.2737, Duration 0:00:00.587941
# Epoch 51/60, Train Loss: 0.0153, Validation Loss: 0.2751, Duration 0:00:00.672366
# Epoch 52/60, Train Loss: 0.0146, Validation Loss: 0.2847, Duration 0:00:00.682580
# Epoch 53/60, Train Loss: 0.0144, Validation Loss: 0.2773, Duration 0:00:00.692390
# Epoch 54/60, Train Loss: 0.0144, Validation Loss: 0.2696, Duration 0:00:00.687663
# Epoch 55/60, Train Loss: 0.0143, Validation Loss: 0.2475, Duration 0:00:00.663619
# Epoch 56/60, Train Loss: 0.0140, Validation Loss: 0.2225, Duration 0:00:00.676408
# Epoch 57/60, Train Loss: 0.0146, Validation Loss: 0.2146, Duration 0:00:00.671882
# Epoch 58/60, Train Loss: 0.0142, Validation Loss: 0.1996, Duration 0:00:00.662220
# Epoch 59/60, Train Loss: 0.0146, Validation Loss: 0.1741, Duration 0:00:00.654405
# Epoch 60/60, Train Loss: 0.0137, Validation Loss: 0.1619, Duration 0:00:00.655541
# Fold 1, final train loss: 0.01375, final train loss: 0.16191
# Epoch 1/60, Train Loss: 0.0139, Validation Loss: 0.1686, Duration 0:00:00.604576
# Epoch 2/60, Train Loss: 0.0137, Validation Loss: 0.1668, Duration 0:00:00.687290
# Epoch 3/60, Train Loss: 0.0135, Validation Loss: 0.1764, Duration 0:00:00.665819
# Epoch 4/60, Train Loss: 0.0135, Validation Loss: 0.1893, Duration 0:00:00.666285
# Epoch 5/60, Train Loss: 0.0140, Validation Loss: 0.1906, Duration 0:00:00.668951
# Epoch 6/60, Train Loss: 0.0137, Validation Loss: 0.1696, Duration 0:00:00.681668
# Epoch 7/60, Train Loss: 0.0133, Validation Loss: 0.1519, Duration 0:00:00.669463
# Epoch 8/60, Train Loss: 0.0132, Validation Loss: 0.1381, Duration 0:00:00.699986
# Epoch 9/60, Train Loss: 0.0133, Validation Loss: 0.1361, Duration 0:00:00.673111
# Epoch 10/60, Train Loss: 0.0133, Validation Loss: 0.1307, Duration 0:00:00.689245
# Epoch 11/60, Train Loss: 0.0131, Validation Loss: 0.1323, Duration 0:00:00.658930
# Epoch 12/60, Train Loss: 0.0129, Validation Loss: 0.1416, Duration 0:00:00.656835
# Epoch 13/60, Train Loss: 0.0134, Validation Loss: 0.1417, Duration 0:00:00.584808
# Epoch 14/60, Train Loss: 0.0128, Validation Loss: 0.1357, Duration 0:00:00.668443
# Epoch 15/60, Train Loss: 0.0130, Validation Loss: 0.1241, Duration 0:00:00.667418
# Epoch 16/60, Train Loss: 0.0130, Validation Loss: 0.1199, Duration 0:00:00.664795
# Epoch 17/60, Train Loss: 0.0130, Validation Loss: 0.1114, Duration 0:00:00.675268
# Epoch 18/60, Train Loss: 0.0128, Validation Loss: 0.1019, Duration 0:00:00.668938
# Epoch 19/60, Train Loss: 0.0128, Validation Loss: 0.0995, Duration 0:00:00.670760
# Epoch 20/60, Train Loss: 0.0130, Validation Loss: 0.0960, Duration 0:00:00.658740
# Epoch 21/60, Train Loss: 0.0130, Validation Loss: 0.0951, Duration 0:00:00.666080
# Epoch 22/60, Train Loss: 0.0127, Validation Loss: 0.0950, Duration 0:00:00.685274
# Epoch 23/60, Train Loss: 0.0125, Validation Loss: 0.1006, Duration 0:00:00.652275
# Epoch 24/60, Train Loss: 0.0127, Validation Loss: 0.1042, Duration 0:00:00.616539
# Epoch 25/60, Train Loss: 0.0125, Validation Loss: 0.0982, Duration 0:00:00.688449
# Epoch 26/60, Train Loss: 0.0127, Validation Loss: 0.0953, Duration 0:00:00.694069
# Epoch 27/60, Train Loss: 0.0127, Validation Loss: 0.0924, Duration 0:00:00.671091
# Epoch 28/60, Train Loss: 0.0126, Validation Loss: 0.0912, Duration 0:00:00.661714
# Epoch 29/60, Train Loss: 0.0126, Validation Loss: 0.0881, Duration 0:00:00.675625
# Epoch 30/60, Train Loss: 0.0126, Validation Loss: 0.0833, Duration 0:00:00.671392
# Epoch 31/60, Train Loss: 0.0125, Validation Loss: 0.0811, Duration 0:00:00.670080
# Epoch 32/60, Train Loss: 0.0126, Validation Loss: 0.0825, Duration 0:00:00.664916
# Epoch 33/60, Train Loss: 0.0124, Validation Loss: 0.0847, Duration 0:00:00.683525
# Epoch 34/60, Train Loss: 0.0127, Validation Loss: 0.0861, Duration 0:00:00.669496
# Epoch 35/60, Train Loss: 0.0124, Validation Loss: 0.0820, Duration 0:00:00.666404
# Epoch 36/60, Train Loss: 0.0124, Validation Loss: 0.0789, Duration 0:00:00.594884
# Epoch 37/60, Train Loss: 0.0124, Validation Loss: 0.0781, Duration 0:00:00.675817
# Epoch 38/60, Train Loss: 0.0124, Validation Loss: 0.0758, Duration 0:00:00.709993
# Epoch 39/60, Train Loss: 0.0125, Validation Loss: 0.0757, Duration 0:00:00.687351
# Epoch 40/60, Train Loss: 0.0125, Validation Loss: 0.0758, Duration 0:00:00.712724
# Epoch 41/60, Train Loss: 0.0123, Validation Loss: 0.0794, Duration 0:00:00.666570
# Epoch 42/60, Train Loss: 0.0122, Validation Loss: 0.0795, Duration 0:00:00.654052
# Epoch 43/60, Train Loss: 0.0123, Validation Loss: 0.0754, Duration 0:00:00.660431
# Epoch 44/60, Train Loss: 0.0123, Validation Loss: 0.0700, Duration 0:00:00.690661
# Epoch 45/60, Train Loss: 0.0124, Validation Loss: 0.0674, Duration 0:00:00.662110
# Epoch 46/60, Train Loss: 0.0121, Validation Loss: 0.0703, Duration 0:00:00.667723
# Epoch 47/60, Train Loss: 0.0125, Validation Loss: 0.0722, Duration 0:00:00.621110
# Epoch 48/60, Train Loss: 0.0123, Validation Loss: 0.0720, Duration 0:00:00.656623
# Epoch 49/60, Train Loss: 0.0124, Validation Loss: 0.0700, Duration 0:00:00.682598
# Epoch 50/60, Train Loss: 0.0123, Validation Loss: 0.0687, Duration 0:00:00.671014
# Epoch 51/60, Train Loss: 0.0126, Validation Loss: 0.0679, Duration 0:00:00.685704
# Epoch 52/60, Train Loss: 0.0124, Validation Loss: 0.0651, Duration 0:00:00.659698
# Epoch 53/60, Train Loss: 0.0122, Validation Loss: 0.0588, Duration 0:00:00.655262
# Epoch 54/60, Train Loss: 0.0123, Validation Loss: 0.0577, Duration 0:00:00.677901
# Epoch 55/60, Train Loss: 0.0123, Validation Loss: 0.0579, Duration 0:00:00.684593
# Epoch 56/60, Train Loss: 0.0124, Validation Loss: 0.0593, Duration 0:00:00.657739
# Epoch 57/60, Train Loss: 0.0121, Validation Loss: 0.0621, Duration 0:00:00.684542
# Epoch 58/60, Train Loss: 0.0125, Validation Loss: 0.0639, Duration 0:00:00.654683
# Epoch 59/60, Train Loss: 0.0123, Validation Loss: 0.0614, Duration 0:00:00.601258
# Epoch 60/60, Train Loss: 0.0123, Validation Loss: 0.0581, Duration 0:00:00.660480
# Fold 2, final train loss: 0.01229, final train loss: 0.05815
# Epoch 1/60, Train Loss: 0.0121, Validation Loss: 0.0598, Duration 0:00:00.668019
# Epoch 2/60, Train Loss: 0.0122, Validation Loss: 0.0611, Duration 0:00:00.687603
# Epoch 3/60, Train Loss: 0.0122, Validation Loss: 0.0602, Duration 0:00:00.681121
# Epoch 4/60, Train Loss: 0.0121, Validation Loss: 0.0607, Duration 0:00:00.664867
# Epoch 5/60, Train Loss: 0.0123, Validation Loss: 0.0605, Duration 0:00:00.676883
# Epoch 6/60, Train Loss: 0.0121, Validation Loss: 0.0607, Duration 0:00:00.682841
# Epoch 7/60, Train Loss: 0.0120, Validation Loss: 0.0649, Duration 0:00:00.672440
# Epoch 8/60, Train Loss: 0.0121, Validation Loss: 0.0638, Duration 0:00:00.689493
# Epoch 9/60, Train Loss: 0.0122, Validation Loss: 0.0600, Duration 0:00:00.674198
# Epoch 10/60, Train Loss: 0.0120, Validation Loss: 0.0576, Duration 0:00:00.596804
# Epoch 11/60, Train Loss: 0.0127, Validation Loss: 0.0576, Duration 0:00:00.665998
# Epoch 12/60, Train Loss: 0.0122, Validation Loss: 0.0570, Duration 0:00:00.672452
# Epoch 13/60, Train Loss: 0.0121, Validation Loss: 0.0578, Duration 0:00:00.703364
# Epoch 14/60, Train Loss: 0.0120, Validation Loss: 0.0586, Duration 0:00:00.654217
# Epoch 15/60, Train Loss: 0.0121, Validation Loss: 0.0595, Duration 0:00:00.658135
# Epoch 16/60, Train Loss: 0.0119, Validation Loss: 0.0606, Duration 0:00:00.657430
# Epoch 17/60, Train Loss: 0.0121, Validation Loss: 0.0611, Duration 0:00:00.678975
# Epoch 18/60, Train Loss: 0.0127, Validation Loss: 0.0589, Duration 0:00:00.704790
# Epoch 19/60, Train Loss: 0.0120, Validation Loss: 0.0564, Duration 0:00:00.652855
# Epoch 20/60, Train Loss: 0.0121, Validation Loss: 0.0554, Duration 0:00:00.657411
# Epoch 21/60, Train Loss: 0.0120, Validation Loss: 0.0544, Duration 0:00:00.656389
# Epoch 22/60, Train Loss: 0.0122, Validation Loss: 0.0538, Duration 0:00:00.632502
# Epoch 23/60, Train Loss: 0.0122, Validation Loss: 0.0526, Duration 0:00:00.671368
# Epoch 24/60, Train Loss: 0.0121, Validation Loss: 0.0519, Duration 0:00:00.656836
# Epoch 25/60, Train Loss: 0.0120, Validation Loss: 0.0525, Duration 0:00:00.671599
# Epoch 26/60, Train Loss: 0.0119, Validation Loss: 0.0541, Duration 0:00:00.660789
# Epoch 27/60, Train Loss: 0.0120, Validation Loss: 0.0560, Duration 0:00:00.673461
# Epoch 28/60, Train Loss: 0.0120, Validation Loss: 0.0552, Duration 0:00:00.668004
# Epoch 29/60, Train Loss: 0.0120, Validation Loss: 0.0525, Duration 0:00:00.666184
# Epoch 30/60, Train Loss: 0.0122, Validation Loss: 0.0516, Duration 0:00:00.677575
# Epoch 31/60, Train Loss: 0.0119, Validation Loss: 0.0510, Duration 0:00:00.691405
# Epoch 32/60, Train Loss: 0.0121, Validation Loss: 0.0511, Duration 0:00:00.668200
# Epoch 33/60, Train Loss: 0.0120, Validation Loss: 0.0511, Duration 0:00:00.603119
# Epoch 34/60, Train Loss: 0.0119, Validation Loss: 0.0518, Duration 0:00:00.668779
# Epoch 35/60, Train Loss: 0.0120, Validation Loss: 0.0529, Duration 0:00:00.666816
# Epoch 36/60, Train Loss: 0.0119, Validation Loss: 0.0533, Duration 0:00:00.666007
# Epoch 37/60, Train Loss: 0.0120, Validation Loss: 0.0525, Duration 0:00:00.651169
# Epoch 38/60, Train Loss: 0.0118, Validation Loss: 0.0519, Duration 0:00:00.663542
# Epoch 39/60, Train Loss: 0.0118, Validation Loss: 0.0519, Duration 0:00:00.679372
# Epoch 40/60, Train Loss: 0.0118, Validation Loss: 0.0520, Duration 0:00:00.658681
# Epoch 41/60, Train Loss: 0.0118, Validation Loss: 0.0515, Duration 0:00:00.670151
# Epoch 42/60, Train Loss: 0.0119, Validation Loss: 0.0517, Duration 0:00:00.691084
# Epoch 43/60, Train Loss: 0.0119, Validation Loss: 0.0531, Duration 0:00:00.662933
# Epoch 44/60, Train Loss: 0.0121, Validation Loss: 0.0528, Duration 0:00:00.695340
# Epoch 45/60, Train Loss: 0.0119, Validation Loss: 0.0518, Duration 0:00:00.593767
# Epoch 46/60, Train Loss: 0.0120, Validation Loss: 0.0502, Duration 0:00:00.665402
# Epoch 47/60, Train Loss: 0.0119, Validation Loss: 0.0488, Duration 0:00:00.661887
# Epoch 48/60, Train Loss: 0.0117, Validation Loss: 0.0484, Duration 0:00:00.687317
#   0%|          | 0/100 [02:10<?, ?trial/s, best loss=?]

# %%
print(best)

# %%
plt.plot(train_losses, label='train loss')
plt.plot(val_losses, label='validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Generate predictions

# %%
def predict(model, device, data_loader):
    model.eval()
    preds = []

    for inputs, _ in data_loader:
        inputs = inputs.to(device)

        with torch.no_grad():
            outputs = model(inputs)

        preds.append(outputs.detach().cpu().numpy())

    preds = np.concatenate(preds)

    return preds

test_dataset = MoaDataset(X_test, None, mode='eval')
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)
preds = predict(model, device, test_loader)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-88d94c939eea> in <module>
#      15     return preds
#      16
# ---> 17 test_dataset = MoaDataset(X_test, None, mode='eval')
#      18 test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)
#      19 preds = predict(model, device, test_loader)
#
# NameError: name 'MoaDataset' is not defined

# %%
targets = [col for col in train_targets.columns]
sample_submission[targets] = preds
sample_submission.loc[test_features['cp_type']=='ctl_vehicle', targets] = 0
sample_submission.to_csv('submission.csv', index=False)

# %% [markdown]
# ### Model evaluation

# %%
train_dataset = MoaDataset(X_original, None, mode='eval')
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=False)
mock_preds = predict(model, device, train_loader)

# %%
loss_fn = nn.BCELoss()

y_pred = torch.from_numpy(mock_preds.astype(float))
y_true = torch.from_numpy(Y_original.astype(float))

score = loss_fn(y_pred, y_true)
print("log-loss score: ", score.item())

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score

# compute ROC AUC curve and AUC score using micro-averaging
fpr, tpr, _ = roc_curve(y_true.ravel(), y_pred.ravel())
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange',
         lw=2, label='ROC curve (area = %0.4f)' % roc_auc)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Aggregate ROC curve (micro-averaging)')
plt.legend(loc="lower right")
plt.show()

print("ROC AUC score: ", roc_auc_score(y_true, y_pred, average='micro'))

# %%
from sklearn.metrics import multilabel_confusion_matrix

decision_boundary = 0.5
confusion_matrices = multilabel_confusion_matrix(y_true, (y_pred > decision_boundary))

agg_confusion_matrix = np.array([[0, 0],  # [tn, fp]
                                 [0, 0]])  # [fn, tp]
for m in confusion_matrices:
    agg_confusion_matrix += m

print(agg_confusion_matrix)
